# %%
import pandas as pd

# %%
nameslist3 = pd.read_csv('nameslist3.csv')
nameslist4 = pd.read_csv('nameslist4.csv')
missing_name_list_update = pd.read_csv('missing_name_list_update.csv')

# %%
missing_name_list_update = missing_name_list_update[['name', 'zip']]

# %%
merged_df_step_1 = missing_name_list_update.merge(nameslist3, left_on='name', right_on='name')
merged_df_step_2 = missing_name_list_update.merge(nameslist4, left_on='name', right_on='name')
merged_df = pd.concat([merged_df_step_1, merged_df_step_2])
# merged_df.to_csv('extra_fips.csv')
merged_df
# Out:
# C:\Users\marti\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#        FIPS  Unnamed: 0     X       county     fips  \
# 0       NaN        6664   NaN        Ocean    34029
# 1       NaN        4286   NaN       Iberia    22045
# 2       NaN        7006   NaN       Nassau    36059
# 3       NaN        2457   NaN     Pinellas    12103
# 4       NaN        7584   NaN  Westchester    36119
# 5       NaN        4815   NaN    Middlesex    25017
# 6       NaN        2452   NaN     Pinellas    12103
# 7       NaN        7928   NaN     Cuyahoga    39035
# 8       NaN        2939   NaN     Gwinnett    13135
# ...

# %%
missing_names_no_fips.to_csv('missing_names_fips.csv')

# %%
zip_to_fips = pd.read_csv('ZIP-COUNTY-FIPS_2017-06.csv')

# %%
state_codes = {
    'WA': '53', 'DE': '10', 'DC': '11', 'WI': '55', 'WV': '54', 'HI': '15',
    'FL': '12', 'WY': '56', 'PR': '72', 'NJ': '34', 'NM': '35', 'TX': '48',
    'LA': '22', 'NC': '37', 'ND': '38', 'NE': '31', 'TN': '47', 'NY': '36',
    'PA': '42', 'AK': '02', 'NV': '32', 'NH': '33', 'VA': '51', 'CO': '08',
    'CA': '06', 'AL': '01', 'AR': '05', 'VT': '50', 'IL': '17', 'GA': '13',
    'IN': '18', 'IA': '19', 'MA': '25', 'AZ': '04', 'ID': '16', 'CT': '09',
    'ME': '23', 'MD': '24', 'OK': '40', 'OH': '39', 'UT': '49', 'MO': '29',
    'MN': '27', 'MI': '26', 'RI': '44', 'KS': '20', 'MT': '30', 'MS': '28',
    'SC': '45', 'KY': '21', 'OR': '41', 'SD': '46', 'VI': '52'
}

# %%
zip_to_fips.replace({"STATE": state_codes})
# Out:
#          ZIP               COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0      36003           Autauga County    01        1001      H1
# 1      36006           Autauga County    01        1001      H1
# 2      36067           Autauga County    01        1001      H1
# 3      36066           Autauga County    01        1001      H1
# 4      36703           Autauga County    01        1001      H1
# 5      36701           Autauga County    01        1001      H1
# 6      36091           Autauga County    01        1001      H1
# 7      36051           Autauga County    01        1001      H1
# 8      36068           Autauga County    01        1001      H1
# 9      36008           Autauga County    01        1001      H1
# 10     36022           Autauga County    01        1001      H1
# 11     36749           Autauga County    01        1001      H1
# 12     36758           Autauga County    01        1001      H1
# 13     36550           Baldwin County    01        1003      H1
# ...

# %%
zip_to_fips.to_csv('zip_to_fips.csv')
