# %%
import pandas as pd
import string

# %%
df = pd.read_csv('name_zip_fips_state.csv', dtype = str)

# %%
name_list = df['name']
last_name_list = []
name_extentions_list = ['jr', 'i', 'ii', 'iii', 'iv', 'v', 'vi', 'sr', 'jd', 'rn', 'bsn', 'cpa', 'cgma', 'ctp', 'mba', 'cma', 'pe', 'esq', '-']
for name in name_list:
    while ',' in name:
        name = name.split(',')[0]
    while ' (' in name:
        name = name.split(' (')[0]
    name = name.split(' ')
    i = -1
    last_name_found = False
    while last_name_found == False:
        if any(name_suf == name[i].lower() for name_suf in name_extentions_list):
            i -= 1
        elif '.' in name[i]:
            i -= 1
        else:
            last_name_list.append(name[i])
            last_name_found = True
last_name_list
# Out:
# ['Richardson',
#  'Turner',
#  'Wambach',
#  'Guarino',
#  'Orederu',
#  'Comba',
#  'MacDonald',
#  'Banks',
#  'Tomlinson',
#  'Cherry',
#  'Purcell',
#  'Fawal',
#  'Hayes',
#  'Hood',
#  'Ramos',
#  'Mastracci',
#  'Datz',
#  'Williams',
#  'Williams',
#  'Balbo',
#  'Hinton',
#  'Leeds',
#  'Kemp',
#  'Tonn',
#  'Benassi',
#  'Martinson',
#  'Bey',
#  'Danovich',
#  'Nalu',
#  'Dilley',
#  'Khalil',
#  'Gibbs',
#  'Spinella',
#  'Weissenstein',
#  'Lomonaco',
#  'Sanders',
#  'Friday',
#  'Snell',
#  'Thomson',
#  'Gloeser',
#  'Sirna',
#  'DeCaro',
#  'Janklow',
#  'Chase',
#  'Tillery',
#  'Mattingly',
#  'McManes',
#  'Hunter',
#  'Tauke',
#  'James',
#  'Lucas',
#  'Mander',
#  'Angelis',
#  'Krolik',
#  'Amore',
#  'Gregg',
#  'Denton',
#  'Johnson',
#  'Ryan',
#  'Felton',
#  'Randall',
#  'Bundy',
#  'Crane',
#  'Delgado',
#  'Eiesland',
#  'Lauter',
#  'Salberg',
#  'Speck',
#  'Wiseley',
#  'Glazer',
#  'Allison',
#  'Garrett',
#  'Ginkens',
#  'Allen',
#  'Broussard',
#  'Rolen',
#  'Jainchill',
#  'House',
#  'Kelly',
#  'Reed',
#  'Woods',
#  'Maurice',
#  'Sobel',
#  'Ritchie',
#  'Rodgers',
#  'Hicks',
#  'Ferguson',
#  'Graves',
#  'Rapier',
#  'Rodenburg',
#  'Smith',
#  'Watson',
#  'Sachs',
#  'Jolles',
#  'Fenichel',
#  'Spears',
#  'Richardson',
#  'Innabi',
#  'Saadiq',
#  'Omerhodic',
#  'Paul',
#  'Orendain',
#  'Reyna',
#  'Cardenas',
#  'Mayers',
#  'Saad',
#  'Nievod',
#  'Kassis',
#  'Reingold',
#  'Barreto',
#  'Studnicki',
#  'Brown',
#  'Kuenning',
#  'Lederman',
#  'Riback',
#  'Schwartz',
#  'Barnett',
#  'Loeb',
#  'Carlson',
#  'Chrzan',
#  'Collins',
#  'Blechman',
#  'Herzog',
#  'Young',
#  'Davis',
#  'Demetri',
#  'Bossov',
#  'Carr',
#  'Schramm',
#  'Evans',
#  'Flores',
#  'Cross',
#  'Getson',
#  'Hill',
#  'Malinowski',
#  'Bean',
#  'Blank',
#  'Curry',
#  'Resmini',
#  'Soibelman',
#  'Tabak',
#  'Teller',
#  'Wax',
#  'Russo',
#  'Vernau',
#  'Rodd',
#  'Brown',
#  'Jurach',
#  'Stefancic',
#  'Malone',
#  'Mazonson',
#  'Meltsner',
#  'Cerbone',
#  'Kossayda',
#  'Prochaska',
#  'Pugh',
#  'Glinn',
#  'Baker',
#  'Bernstein',
#  'Hall',
#  'Weintraub',
#  'Symington',
#  'Johnson',
#  'Williamson',
#  'Trop',
#  'Goff',
#  'Blackmore',
#  'Jacobs',
#  'Horan',
#  'Lara',
#  'Anarado',
#  'Levy',
#  'Sicheri',
#  'Ellis',
#  'Dunning',
#  'Hunte',
#  'Altshuler',
#  'Hoosier',
#  'Wasko',
#  'Meyer',
#  'Peguese',
#  'Hershey',
#  'Villarreal',
#  'Pickard',
#  'Snelling',
#  'Logeman',
#  'Burke',
#  'Baranoff',
#  'Klein',
#  'Hahn',
#  'Davis',
#  'King',
#  'Raynor',
#  'Petersen',
#  'Ribeiro',
#  'Cammisa',
#  'Reynolds',
#  'Su',
#  'Dyches',
#  'Droughton',
#  'Leipprandt',
#  'Rabalais',
#  'Murphy',
#  'Moshaiv',
#  'Amer',
#  'Iacocca',
#  'Carrion',
#  'Schallau',
#  'Hom',
#  'Tamuno',
#  'Carrico',
#  'Aleksander',
#  'Alhadeff',
#  'Weber',
#  'Fish',
#  'Havis',
#  'Neurick',
#  'Waln',
#  'Banov',
#  'Bellenger',
#  'Miller',
#  'Geohagan',
#  'Anchell',
#  'Betz',
#  'Espy',
#  'Taylor',
#  'Bell',
#  'Budman',
#  'Henderson',
#  'Levine',
#  'Watson',
#  'Toll',
#  'Varner',
#  'Smietanski',
#  'Floria',
#  'Blatnikoff',
#  'Greenberg',
#  'Ginsberg',
#  'Greer',
#  'Greenberg',
#  'Barbanel',
#  'Hunt',
#  'Schimmel',
#  'Markman',
#  'Ominsky',
#  'Baldwin',
#  'Belsky',
#  'Booth',
#  'Cohen',
#  'Golden',
#  'Konigsberg',
#  'Nuta',
#  'Statman',
#  'Braverman',
#  'Foxman',
#  'Lander',
#  'Lerner',
#  'Stratton',
#  'Foe',
#  'Kansas',
#  'Kolod',
#  'Kreshtool',
#  'Mealy',
#  'Joseph',
#  'Newman',
#  'Schwalbe',
#  'Sirkin',
#  'Whitted',
#  'Kraut',
#  'Tanenbaum',
#  'Tepper',
#  'Greenberg',
#  'Purdie',
#  'Salkow',
#  'Wolinsky',
#  'Foody',
#  'Molina',
#  'Molina',
#  'Bayham',
#  'Dove',
#  'Taylor',
#  'Pearlman',
#  'Davis',
#  'Beard',
#  'Cochran',
#  'Goodman',
#  'Lebowitz',
#  'LeCours',
#  'Levy',
#  'Pfaff',
#  'Kolodny',
#  'Roberts',
#  'Rosenberg',
#  'Baum',
#  'Dambrov',
#  'Friedman',
#  'Funk',
#  'Gold',
#  'Levine',
#  'Pierce',
#  'Miller',
#  'Pickel',
#  'Silko',
#  'Starker',
#  'Stegall',
#  'Rubin',
#  'Sylvester',
#  'Johnson',
#  'Cohn',
#  'Wagner',
#  'Medvin',
#  'Clements',
#  'Henry',
#  'Dunisha',
#  'Biel',
#  'Wolf',
#  'Aaron',
#  'Mitchell',
#  'Dragon',
#  'Davies',
#  'Desrosiers',
#  'Fershing',
#  'Hollan',
#  'Jones',
#  'Moon',
#  'Ranum',
#  'Maier',
#  'Ries',
#  'Shamash',
#  'Farrah',
#  'Hubby',
#  'Guadagno',
#  'Rescinio',
#  'Sreter',
#  'Bannon',
#  'DeCusati',
#  'Fiorella',
#  'Slap',
#  'Bolet',
#  'Saslow',
#  'Wheeler',
#  'Messer',
#  'Pearson',
#  'Thiel',
#  'Matthews',
#  'Lazarus',
#  'Salvi',
#  'Huff',
#  'Chianese',
#  'Cornachio',
#  'Miller',
#  'Berrones',
#  'Franco',
#  'Guadagno',
#  'Virgen',
#  'Harrington',
#  'Beltrano',
#  'Stolte',
#  'Hanus',
#  'Wisner',
#  'Elston',
#  'Szwarcsztejn',
#  'Fiol',
#  'Rodriguez',
#  'Days',
#  'Strand',
#  'Marra',
#  'Giribaldi',
#  'Lauricella',
#  'Omrani',
#  'Scheingross',
#  'Wallach',
#  'Dunn',
#  'Elder',
#  'Chapman',
#  'Cheng',
#  'Philippone',
#  'Ghibaudo',
#  'Goldberg',
#  'Sitz',
#  'Hanna',
#  'Miller',
#  'Remick',
#  'Kapetan',
#  'Rabin',
#  'Friedland',
#  'Postic',
#  'Nocerino',
#  'Russell',
#  'Wright',
#  'Barrera',
#  'Begum',
#  'Boyd',
#  'Crecca',
#  'Sklavos',
#  'Reichert',
#  'Hait',
#  'Rozman',
#  'Gordon',
#  'Jamiolkowski',
#  'Kemeny',
#  'Smith',
#  'Ginsburg',
#  'Alfano',
#  'Davison',
#  'Karasik',
#  'Latanision',
#  'Levine',
#  'Silow',
#  'Lumelsky',
#  'Dashe',
#  'Weinberg',
#  'Levay',
#  'Cain',
#  'Kammer',
#  'Simanovsky',
#  'Mora',
#  'Hull',
#  'Schultz',
#  'Bonin',
#  'Pittas-Giroux',
#  'Langella',
#  'Mullaney',
#  'Sivertson',
#  'Langan',
#  'Haselden',
#  'Levingston',
#  'Veltri',
#  'Castillo',
#  'Mencuccini',
#  'Laub',
#  'Marotta',
#  'Howell',
#  'Chan',
#  'Verderose',
#  'Powell',
#  'Allgood',
#  'Anthony',
#  'Fazio',
#  'Corriere',
#  'Paniccia',
#  'Denowitz',
#  'Beresko',
#  'Keep',
#  'McGill',
#  'Altopiedi',
#  'Gellene',
#  'Evangelista',
#  'Hakeem',
#  'Ramadan',
#  'Buffington',
#  'Malleris',
#  'Mansfield',
#  'Beasley',
#  'London',
#  'Rodriguez',
#  'Freeze',
#  'Chalumeau',
#  'Curran',
#  'Marcantonio',
#  'George',
#  'Fermaglich',
#  'Wells',
#  'Hershewe',
#  'Gokal',
#  'Franklin',
#  'Haynes',
#  'Talbert',
#  'Briggs',
#  'Wool',
#  'Magenheim',
#  'Adkinson',
#  'Wong',
#  'Arabo',
#  'Duroseau',
#  'Sanders',
#  'Hardin',
#  'Berger',
#  'Breslin',
#  'Orsborn',
#  'Perry',
#  'VanDeMark',
#  'Curry',
#  'Goldstein',
#  'Levin',
#  'Davis',
#  'Shapiro',
#  'Rombro',
#  'Bell',
#  'Kalish',
#  'Kornblau',
#  'Ray',
#  'Sagot',
#  'Jaffe',
#  'Plimack',
#  'MacDougall',
#  'Potter',
#  'Lewis',
#  'Cramer',
#  'White',
#  'Chason',
#  'Studenberg',
#  'Downen',
#  'Carpenter',
#  'Engerman',
#  'Jones',
#  'Speare',
#  'Kincannon',
#  'Place',
#  'Glazer',
#  'Ertel',
#  'Moss',
#  'Schuldenfrei',
#  'Kwawer',
#  'Rosner',
#  'Brown',
#  'Fugate',
#  'Wolf',
#  'Stewart',
#  'Mills',
#  'Allweiss',
#  'Ball',
#  'Desmond',
#  'Prunty',
#  'Weed',
#  'Seaman',
#  'Gabe',
#  'Tittle',
#  'Davis',
#  'Lindsay',
#  'Martincavage',
#  'Williams',
#  'Fagerman',
#  'Lane',
#  'Walsh',
#  'Hockman',
#  'McKenzie',
#  'Gilman',
#  'Hymel',
#  'Lampert',
#  'Bridges',
#  'Kinnier',
#  'Lee',
#  'Beauparlant',
#  'Rowe',
#  'Defillo-Millman',
#  'Stempuzis',
#  'Kale',
#  'Hearns',
#  'Nunez',
#  'Maglio',
#  'Prillaman',
#  'Hale',
#  'Haynes',
#  'Smith',
#  'Watson',
#  'Mokhtari',
#  'Owens',
#  'Areces',
#  'Knight',
#  'Hersh',
#  'Dorfman',
#  'Levie',
#  'Wells',
#  'Ziontz',
#  'Peters',
#  'Boucher',
#  'Nathanson',
#  'Barlow',
#  'Luckey',
#  'Richard',
#  'Dotson',
#  'Sullivan',
#  'Phillips',
#  'Bomze',
#  'Poole',
#  'Pershan',
#  'Nath',
#  'Lucero',
#  'Shah',
#  'Mingo',
#  'Houser',
#  'Musselwhite',
#  'Yenerall',
#  'Davis',
#  'Darby',
#  'Paye',
#  'Sanders',
#  'Brinton',
#  'Donnell',
#  'Hinshaw',
#  'Burke',
#  'Como',
#  'Furth',
#  'Gehring',
#  'Morris',
#  'Wills',
#  'Stern',
#  'Stevens',
#  'Reiter',
#  'Chang',
#  'Green',
#  'Zafur',
#  'Weisman',
#  'Carvalho',
#  'Bhargava',
#  'Winer-Gebhart',
#  'Kaimer',
#  'Pallante',
#  'Padron-Fragetta',
#  'Santos',
#  'Borza',
#  'Buckman',
#  'Ladan',
#  'Navare',
#  'Alo',
#  'Blair',
#  'Acheson',
#  'Goldstein',
#  'Vandeveld',
#  'Quillen',
#  'Crossan',
#  'Thomas',
#  'Yenari',
#  'Gowan',
#  'Mariani',
#  'Cofield-Derrick',
#  'Salladay',
#  'Rudley',
#  'Skelton',
#  'Stoner',
#  'Allred',
#  'Keiser',
#  'Bailey',
#  'Vesely',
#  'Hart',
#  'Witherite',
#  'Brewer',
#  'Gervich',
#  'Gillette',
#  'Insler',
#  'Mitchell',
#  'Patras',
#  'Sergent',
#  'Vaudreuil',
#  'Lorenz',
#  'Wille',
#  'Combs',
#  'Johnston',
#  'Keating',
#  'Orsi',
#  'Morse',
#  'Tobias',
#  'Boring',
#  'Turos',
#  'Wheatley',
#  'Winsten',
#  'Snell',
#  'Griggs',
#  'Boyer',
#  'Taylor',
#  'Urness',
#  'Fritz',
#  'Olivares',
#  'Gutierrez',
#  'Molleda',
#  'Aparicio',
#  'Schmidt',
#  'McNamara',
#  'Sardi',
#  'Jacobs',
#  'Sondergaard',
#  'Misra',
#  'Gordon',
#  'Levinsky',
#  'Cox',
#  'Hatfield',
#  'Washburn',
#  'Svikis',
#  'Dorval',
#  'Summers',
#  'Dandurand',
#  'Regard',
#  'Crenshaw',
#  'Lagomarsino',
#  'Michniak',
#  'Young',
#  'Amodeo-Vickery',
#  'Anderson',
#  'Caro',
#  'McMillan',
#  'Miller',
#  'Watters',
#  'Green',
#  'Huston',
#  'Baron',
#  'Sugar',
#  'Ciobanu',
#  'Heckler',
#  'Pawlak',
#  'Shapiro',
#  'Henson',
#  'Bateman',
#  'Carty',
#  'Winder',
#  'Alonso',
#  'Almanzan',
#  'Cos',
#  'Aranda',
#  'Dunlap',
#  'Szakaly',
#  'Agard',
#  'Artus',
#  'Ballerini',
#  'Cohen',
#  'Iacobelli',
#  'Kimler',
#  'Lemmon',
#  'Prolman',
#  'Smith',
#  'Solomon',
#  'Ausband',
#  'Ezell',
#  'Farley',
#  'Miller',
#  'Protzman',
#  'Smith',
#  'Sommerman',
#  'Spiegel',
#  'Bakos',
#  'Bayer',
#  'Beal',
#  'Bersin',
#  'Clifford',
#  'Barr',
#  'Burrell',
#  'Clarke',
#  'Eckert',
#  'Johnson',
#  'Schnack',
#  'Skinner',
#  'Chafin',
#  'Lease',
#  'Stebbins',
#  'Grimes',
#  'Glasgrow',
#  'Huppert',
#  'Jones',
#  'Presberg',
#  'Sabetta',
#  'Stone',
#  'Swain',
#  'Tabenkin',
#  'Greenwald',
#  'Karim',
#  'Feske',
#  'Garruto',
#  'Russo',
#  'Stasio',
#  'Fulkerson',
#  'Ramon',
#  'Schrader',
#  'Storie',
#  'Norton',
#  'Agatston',
#  'Haas',
#  'Marty',
#  'Quinn',
#  'Wood',
#  'Harakas',
#  'Drucker',
#  'Hoverman',
#  'Hamelsky',
#  'Renda',
#  'Bainbridge',
#  'Brown',
#  'Cafiero',
#  'Gibbs',
#  'Gibbs',
#  'Kinstler',
#  'Kutsulis',
#  'Mallon',
#  'McCumber',
#  'Morrissey',
#  'Keefe',
#  'Reinhardt',
#  'Rodnite',
#  'Rossetti',
#  'Schatkin',
#  'Smithart',
#  'Thompson',
#  'Jacobs',
#  'Peters',
#  'Calcagno',
#  'Johnson',
#  'Jacoby',
#  'Kossover',
#  'Drapkin',
#  'Ellenberg',
#  'Miller',
#  'Shapiro',
#  'Laplante',
#  'Statmore',
#  'Liefer',
#  'Tillem',
#  'Abraham',
#  'Barker',
#  'Carroll',
#  'Casey',
#  'Friedman',
#  'Korduba',
#  'Kulick',
#  'Laskin',
#  'Newcomb',
#  'Rockman',
#  'Romano',
#  'Wubbenhorst',
#  'Yoder',
#  'Skier',
#  'McGee',
#  'Sacks',
#  'Montroy',
#  'Mooney',
#  'Cassas',
#  'Greher',
#  'Nestor',
#  'Carrington',
#  'Ott',
#  'Botti',
#  'Cioffi',
#  'Mazzeo',
#  'Motel',
#  'Walsh',
#  'McGraw',
#  'Hamil',
#  'Kirschner',
#  'Liverman',
#  'Louis',
#  'Macklin',
#  'Pauley',
#  'Schwing',
#  'Steiker',
#  'Wolf',
#  'Dempster',
#  'Rosner',
#  'Mackenzie',
#  'Rubin',
#  'Magdy',
#  'Blumer',
#  'Nason',
#  'Abramson',
#  'Baker',
#  'Caslowitz',
#  'Goldwyn',
#  'Murrie',
#  'Muth',
#  'Viola',
#  'Wainwright',
#  'Schwarz',
#  'Epstein',
#  'Henschel',
#  'Shaul',
#  'Sher',
#  'Skemp',
#  'Sky',
#  'Slepian',
#  'Garvis',
#  'Adams',
#  'Blum',
#  'Houghton',
#  'Neuwirth',
#  'Richardson',
#  'Sheeley',
#  'Tarry',
#  'Chasse',
#  'Bokar',
#  'Horn',
#  'Jones',
#  'Seibert',
#  'Siegel',
#  'Snyder',
#  'Yung',
#  'Willers',
#  'Wise',
#  'Wilson',
#  'Wolfenson',
#  'Wolff',
#  'Kim',
#  'Yiangou',
#  'Zelman',
#  'Johnson',
#  'Hayes',
#  'Hensler',
#  'Long',
#  'Rose',
#  'Yun',
#  'Stewart',
#  'Figueredo',
#  'Sanez',
#  'Diaz',
#  'Greene',
#  'Kirk',
#  'Wiggins',
#  'Tekell',
#  'Frazier',
#  'Stevens',
#  'Caine-Turner',
#  'Snider',
#  'Landes',
#  'Dailey',
#  'Elpers',
#  'Keck',
#  'Arellanes',
#  'Burmeister',
#  'Cancio',
#  'Pollard',
#  'Hartmann',
#  'Vagotis',
#  'Vecchio',
#  'McDonald',
#  'Caldwell',
#  'Plakas',
#  'Ziotas',
#  'Morresi',
#  'Testa',
#  'Cicchiello',
#  'Marino',
#  'Simone',
#  'Wright',
#  'Taff',
#  'Avetisyan',
#  'Azadian',
#  'Taneja',
#  'Webster',
#  'Johnson',
#  'Steenson',
#  'Guidoux',
#  'Hotchkiss',
#  'Adams',
#  'Modak-Truran',
#  'Meara',
#  'Ganguly',
#  'Sharma',
#  'Perkins',
#  'Price',
#  'Buckley',
#  'Leslie',
#  'Foley',
#  'Davis',
#  'Washburn',
#  'Brandau',
#  'Staley',
#  'Nowak',
#  'Jones',
#  'Lawler',
#  'Steffens',
#  'Worthington',
#  'Cushing',
#  'Stockmaster',
#  'Tessneer',
#  'Tobin-Levigne',
#  'Trzynka',
#  'Henderson',
#  'Combs',
#  'Barker',
#  'Isobe',
#  'Sheeley',
#  'Siddall',
#  'Curry',
#  'Frank',
#  'Trehub',
#  'Hopcroft',
#  'Carter',
#  'Burr',
#  'Ortiz',
#  'Resnick',
#  'Williams',
#  'Guerra',
#  'Petosky',
#  'Scheurich',
#  'Villarreal',
#  'Moore',
#  'Donovan',
#  'Fowler',
#  'Rice',
#  'Skau',
#  'Leahey',
#  'Brown',
#  'Seider',
#  'Fraser',
#  'Ford',
#  'Daddario',
#  'Kepner',
#  'LaBella',
#  'Guillory',
#  'Manley',
#  'Watkins',
#  'Berger',
#  'Heyns',
#  'Morgan',
#  ...]

# %%
name_list = [x.split(' ') for x in df['name']]
full_name_last_name_zip = list(zip(name_list, last_name_list))
full_name_last_name_zip
# Out:
# [(['A', 'Allsbrook', 'Richardson'], 'Richardson'),
#  (['A', 'Elizabeth', 'Turner'], 'Turner'),
#  (['A', 'J', 'Wambach'], 'Wambach'),
#  (['A', 'Joseph', 'Guarino'], 'Guarino'),
#  (['A', 'Omotayo', 'Orederu'], 'Orederu'),
#  (['A', 'Randolph', 'Comba'], 'Comba'),
#  (['A.', 'Blake', 'MacDonald'], 'MacDonald'),
#  (['A.', 'Bowdre', 'Banks', 'Jr.'], 'Banks'),
#  (['A.', 'Bryan', 'Tomlinson'], 'Tomlinson'),
#  (['A.', 'Collin', 'Cherry,', 'Esquire'], 'Cherry'),
#  (['A.', 'Craig', 'Purcell'], 'Purcell'),
#  (['A.', 'David', 'Fawal'], 'Fawal'),
#  (['A.', 'Dawn', 'Hayes'], 'Hayes'),
#  (['A.', 'Dwight', 'Hood'], 'Hood'),
#  (['A.', 'Gregory', 'Ramos'], 'Ramos'),
#  (['A.', 'Gus', 'Mastracci'], 'Mastracci'),
#  (['A.', 'Harold', 'Datz'], 'Datz'),
#  (['A.', 'Howard', 'Williams'], 'Williams'),
#  (['A.', 'I.', 'Stacey', 'Williams'], 'Williams'),
#  (['A.', 'J.', 'Balbo,', 'Esq.'], 'Balbo'),
#  (['A.', 'Jack', 'Hinton'], 'Hinton'),
#  (['A.', 'James', 'Leeds'], 'Leeds'),
#  (['A.', 'Jeff', 'Kemp'], 'Kemp'),
#  (['A.', 'Lance', 'Tonn'], 'Tonn'),
#  (['A.', 'Lou', 'Benassi'], 'Benassi'),
#  (['A.', 'Mac', 'Martinson'], 'Martinson'),
#  (['A.', 'Major', 'Bey'], 'Bey'),
#  (['A.', 'Mark', 'O', 'Danovich'], 'Danovich'),
#  (['A.', 'Michael', 'Nalu'], 'Nalu'),
#  (['A.', 'Newton', 'Dilley'], 'Dilley'),
#  (['A.', 'O.', 'Khalil,', 'Esq.'], 'Khalil'),
#  (['A.', 'P.', 'Gibbs,', 'Esq.'], 'Gibbs'),
#  (['A.', 'Paul', 'Spinella'], 'Spinella'),
#  (['A.', 'Paul', 'Weissenstein', 'Jr.'], 'Weissenstein'),
#  (['A.', 'Philip', 'Lomonaco'], 'Lomonaco'),
#  (['A.', 'Powell', 'Sanders'], 'Sanders'),
#  (['A.', 'Randall', 'Friday'], 'Friday'),
#  (['A.', 'Richard', 'Snell'], 'Snell'),
#  (['A.', 'Robert', 'E.', 'Thomson'], 'Thomson'),
#  (['A.', 'Robert', 'Gloeser'], 'Gloeser'),
#  (['A.', 'Ronald', 'Sirna', 'Jr.'], 'Sirna'),
#  (['A.', 'Roy', 'DeCaro'], 'DeCaro'),
#  (['A.', 'Russell', 'Janklow'], 'Janklow'),
#  (['A.', 'Scot', 'Chase'], 'Chase'),
#  (['A.', 'Scott', 'Tillery'], 'Tillery'),
#  (['A.', 'Shane', 'Mattingly'], 'Mattingly'),
#  (['A.', 'Spencer', 'McManes', 'Jr.'], 'McManes'),
#  (['A.', 'Troy', 'Hunter'], 'Hunter'),
#  (['A.', 'W.', 'Tony', 'Tauke'], 'Tauke'),
#  (['A.', 'Wade', 'James'], 'James'),
#  (['A.', 'William', 'Lucas'], 'Lucas'),
#  (['A.r.', 'Mander', 'III.'], 'Mander'),
#  (['Aaron', 'A.', 'De', 'Angelis'], 'Angelis'),
#  (['Aaron', 'Abraham', 'Krolik,', 'Esquire'], 'Krolik'),
#  (['Aaron', 'C', 'Amore'], 'Amore'),
#  (['Aaron', 'C', 'Gregg'], 'Gregg'),
#  (['Aaron', 'C.', 'Denton'], 'Denton'),
#  (['Aaron', 'C.', 'Johnson'], 'Johnson'),
#  (['Aaron', 'Charles', 'Ryan'], 'Ryan'),
#  (['Aaron', 'D', 'Felton'], 'Felton'),
#  (['Aaron', 'D', 'Randall'], 'Randall'),
#  (['Aaron', 'D.', 'Bundy'], 'Bundy'),
#  (['Aaron', 'D.', 'Crane'], 'Crane'),
#  (['Aaron', 'D.', 'Delgado'], 'Delgado'),
#  (['Aaron', 'D.', 'Eiesland'], 'Eiesland'),
#  (['Aaron', 'D.', 'Lauter'], 'Lauter'),
#  (['Aaron', 'D.', 'Salberg'], 'Salberg'),
#  (['Aaron', 'D.', 'Speck'], 'Speck'),
#  (['Aaron', 'David', 'Wiseley'], 'Wiseley'),
#  (['Aaron', 'F.', 'Glazer'], 'Glazer'),
#  (['Aaron', 'Felton', 'Allison'], 'Allison'),
#  (['Aaron', 'Garrett'], 'Garrett'),
#  (['Aaron', 'H.', 'R.', 'Ginkens'], 'Ginkens'),
#  (['Aaron', 'J.', 'Allen'], 'Allen'),
#  (['Aaron', 'J.', 'Broussard'], 'Broussard'),
#  (['Aaron', 'J.', 'Rolen'], 'Rolen'),
#  (['Aaron', 'Jainchill'], 'Jainchill'),
#  (['Aaron', 'M.', 'House'], 'House'),
#  (['Aaron', 'M.', 'Kelly'], 'Kelly'),
#  (['Aaron', 'M.', 'Reed'], 'Reed'),
#  (['Aaron', 'N.', 'Woods'], 'Woods'),
#  (['Aaron', 'R.', 'Maurice'], 'Maurice'),
#  (['Aaron', 'R.', 'Sobel'], 'Sobel'),
#  (['Aaron', 'Ritchie'], 'Ritchie'),
#  (['Aaron', 'Rodgers'], 'Rodgers'),
#  (['Aaron', 'Shawn', 'Hicks,', 'Esq.'], 'Hicks'),
#  (['Aaron', 'W.', 'Ferguson'], 'Ferguson'),
#  (['Aaron', 'W.', 'Graves'], 'Graves'),
#  (['Aaron', 'W.', 'Rapier'], 'Rapier'),
#  (['Aaron', 'W.', 'Rodenburg'], 'Rodenburg'),
#  (['Aaron', 'W.', 'Smith'], 'Smith'),
#  (['Aaron', 'Watson'], 'Watson'),
#  (['Aaron', 'Wm.', 'Sachs'], 'Sachs'),
#  (['Abbe', 'Jolles'], 'Jolles'),
#  (['Abbott', 'S.', 'Fenichel'], 'Fenichel'),
#  (['Abby', 'Marie', 'Spears'], 'Spears'),
#  (['Abby', 'Morrow', 'Richardson'], 'Richardson'),
#  (['Abdalla', 'J', 'Innabi'], 'Innabi'),
#  (['Abdulhakim', 'Saadiq'], 'Saadiq'),
#  (['Abe', 'Omerhodic'], 'Omerhodic'),
#  (['Abe', 'R.', 'Paul'], 'Paul'),
#  (['Abel', 'A.', 'Orendain'], 'Orendain'),
#  (['Abelino', 'Reyna'], 'Reyna'),
#  (['Abraham', 'B', 'Cardenas,', 'Esquire'], 'Cardenas'),
#  (['Abraham', 'J.', 'Mayers'], 'Mayers'),
#  (['Abraham', 'J.', 'Saad'], 'Saad'),
#  (['Abraham', 'Jacob', 'Nievod'], 'Nievod'),
#  (['Abraham', 'P', 'Kassis'], 'Kassis'),
#  (['Abraham', 'Reingold'], 'Reingold'),
#  (['Ada', 'Maria', 'Barreto'], 'Barreto'),
#  (['Adam', 'A.', 'Studnicki'], 'Studnicki'),
#  (['Adam', 'B.', 'Brown'], 'Brown'),
#  (['Adam', 'B.', 'Kuenning'], 'Kuenning'),
#  (['Adam', 'B.', 'Lederman,', 'Esq.'], 'Lederman'),
#  (['Adam', 'B.', 'Riback'], 'Riback'),
#  (['Adam', 'B.', 'Schwartz'], 'Schwartz'),
#  (['Adam', 'Barnett'], 'Barnett'),
#  (['Adam', 'C.', 'Loeb'], 'Loeb'),
#  (['Adam', 'Carlson'], 'Carlson'),
#  (['Adam', 'Chrzan'], 'Chrzan'),
#  (['Adam', 'Collins'], 'Collins'),
#  (['Adam', 'D.', 'Blechman'], 'Blechman'),
#  (['Adam', 'D.', 'Herzog'], 'Herzog'),
#  (['Adam', 'D.', 'Young'], 'Young'),
#  (['Adam', 'Davis'], 'Davis'),
#  (['Adam', 'Demetri'], 'Demetri'),
#  (['Adam', 'E', 'Bossov'], 'Bossov'),
#  (['Adam', 'E.', 'Carr'], 'Carr'),
#  (['Adam', 'E.', 'Schramm'], 'Schramm'),
#  (['Adam', 'Evans'], 'Evans'),
#  (['Adam', 'Flores'], 'Flores'),
#  (['Adam', 'G.', 'Cross'], 'Cross'),
#  (['Adam', 'Getson,', 'Esq.'], 'Getson'),
#  (['Adam', 'Hill'], 'Hill'),
#  (['Adam', 'J', 'Malinowski'], 'Malinowski'),
#  (['Adam', 'J.', 'Bean,', 'Esq.'], 'Bean'),
#  (['Adam', 'J.', 'Blank'], 'Blank'),
#  (['Adam', 'J.', 'Curry'], 'Curry'),
#  (['Adam', 'J.', 'Resmini,', 'Esq.'], 'Resmini'),
#  (['Adam', 'J.', 'Soibelman'], 'Soibelman'),
#  (['Adam', 'J.', 'Tabak'], 'Tabak'),
#  (['Adam', 'J.', 'Teller'], 'Teller'),
#  (['Adam', 'J.', 'Wax'], 'Wax'),
#  (['Adam', 'Joseph', 'Russo'], 'Russo'),
#  (['Adam', 'K.', 'Vernau'], 'Vernau'),
#  (['Adam', 'L.', 'Rodd'], 'Rodd'),
#  (['Adam', 'M.', 'Brown'], 'Brown'),
#  (['Adam', 'M.', 'Jurach'], 'Jurach'),
#  (['Adam', 'M.', 'Stefancic'], 'Stefancic'),
#  (['Adam', 'Malone'], 'Malone'),
#  (['Adam', 'Mazonson'], 'Mazonson'),
#  (['Adam', 'Meltsner'], 'Meltsner'),
#  (['Adam', 'P.', 'Cerbone'], 'Cerbone'),
#  (['Adam', 'P.', 'Kossayda'], 'Kossayda'),
#  (['Adam', 'Prochaska'], 'Prochaska'),
#  (['Adam', 'Pugh'], 'Pugh'),
#  (['Adam', 'R', 'Glinn'], 'Glinn'),
#  (['Adam', 'S.', 'Baker'], 'Baker'),
#  (['Adam', 'S.', 'Bernstein'], 'Bernstein'),
#  (['Adam', 'S.', 'Hall'], 'Hall'),
#  (['Adam', 'Scott', 'Weintraub'], 'Weintraub'),
#  (['Adam', 'Symington'], 'Symington'),
#  (['Adam', 'T.', 'Johnson'], 'Johnson'),
#  (['Adam', 'T.', 'Williamson'], 'Williamson'),
#  (['Adam', 'Trop'], 'Trop'),
#  (['Addison', 'Kennon', 'Goff', 'III'], 'Goff'),
#  (['Adele', 'M.', 'Blackmore'], 'Blackmore'),
#  (['Adele', 'R.', 'Jacobs'], 'Jacobs'),
#  (['Adnan', 'Horan'], 'Horan'),
#  (['Adolfo', 'Lara'], 'Lara'),
#  (['AdoLisa', 'Anarado'], 'Anarado'),
#  (['Adolph', 'J.', 'Levy'], 'Levy'),
#  (['Adolph', 'P.', 'Sicheri'], 'Sicheri'),
#  (['Adrian', 'A.', 'Ellis'], 'Ellis'),
#  (['Adrian', 'B.', 'Dunning'], 'Dunning'),
#  (['Adrian', 'C.', 'Hunte'], 'Hunte'),
#  (['Adrian', 'H.', 'Altshuler'], 'Altshuler'),
#  (['Adrian', 'Hoosier'], 'Hoosier'),
#  (['Adrian', 'J', 'Wasko'], 'Wasko'),
#  (['Adrian', 'L.', 'Meyer'], 'Meyer'),
#  (['Adrian', 'R.', 'Peguese'], 'Peguese'),
#  (['Adrian', 'Vernon', 'Hershey'], 'Hershey'),
#  (['Adriel', 'B.', 'Villarreal'], 'Villarreal'),
#  (['Adrien', 'C.', 'Pickard'], 'Pickard'),
#  (['Adrienne', 'C.', 'Snelling'], 'Snelling'),
#  (['Adrienne', 'D.', 'Logeman'], 'Logeman'),
#  (['Adrienne', 'J.', 'Burke'], 'Burke'),
#  (['Adrienne', 'R', 'Baranoff,', 'Esq.'], 'Baranoff'),
#  (['Adrienne', 'R', 'Klein'], 'Klein'),
#  (['Adrienne', 'Rachel', 'Hahn'], 'Hahn'),
#  (['Adrienne', 'S.', 'Davis'], 'Davis'),
#  (['Adrienne', 'S.', 'King'], 'King'),
#  (['Agatha', 'K.', 'Raynor'], 'Raynor'),
#  (['Agnes', 'M.', 'Petersen'], 'Petersen'),
#  (['Agostinho', 'J.', 'Ribeiro'], 'Ribeiro'),
#  (['Agostino', 'Cammisa'], 'Cammisa'),
#  (['Aidan', 'Cyril', 'Reynolds'], 'Reynolds'),
#  (['Aihui', 'Su'], 'Su'),
#  (['Aiken', 'Fletcher', 'Dyches'], 'Dyches'),
#  (['Aileen', 'Droughton'], 'Droughton'),
#  (['Aileen', 'M.', 'Leipprandt'], 'Leipprandt'),
#  (['Aimee', 'E.', 'Rabalais'], 'Rabalais'),
#  (['Aisling', 'A.', 'Murphy'], 'Murphy'),
#  (['Aksana', 'Moshaiv'], 'Moshaiv'),
#  (['Al', 'F.', 'Amer'], 'Amer'),
#  (['Al', 'Iacocca,', 'Esquire'], 'Iacocca'),
#  (['Al', 'Joseph', 'Carrion'], 'Carrion'),
#  (['Al', 'Schallau'], 'Schallau'),
#  (['Al.', 'Hom'], 'Hom'),
#  (['Alali', 'M', 'Tamuno'], 'Tamuno'),
#  (['Alan', 'A', 'Carrico'], 'Carrico'),
#  (['Alan', 'Aleksander'], 'Aleksander'),
#  (['Alan', 'Alhadeff'], 'Alhadeff'),
#  (['Alan', 'B', 'Weber'], 'Weber'),
#  (['Alan', 'B.', 'Fish'], 'Fish'),
#  (['Alan', 'B.', 'Havis'], 'Havis'),
#  (['Alan', 'B.', 'Neurick'], 'Neurick'),
#  (['Alan', 'B.', 'Waln'], 'Waln'),
#  (['Alan', 'Banov'], 'Banov'),
#  (['Alan', 'Bellenger'], 'Bellenger'),
#  (['Alan', 'Benjamin', 'Miller'], 'Miller'),
#  (['Alan', 'Brent', 'Geohagan'], 'Geohagan'),
#  (['Alan', 'C.', 'Anchell'], 'Anchell'),
#  (['Alan', 'C.', 'Betz'], 'Betz'),
#  (['Alan', 'C.', 'Espy'], 'Espy'),
#  (['Alan', 'D', 'Taylor'], 'Taylor'),
#  (['Alan', 'D.', 'Bell'], 'Bell'),
#  (['Alan', 'D.', 'Budman'], 'Budman'),
#  (['Alan', 'D.', 'Henderson'], 'Henderson'),
#  (['Alan', 'D.', 'Levine'], 'Levine'),
#  (['Alan', 'D.', 'Watson'], 'Watson'),
#  (['Alan', 'E.', 'Toll'], 'Toll'),
#  (['Alan', 'F', 'Varner'], 'Varner'),
#  (['Alan', 'F.', 'Smietanski'], 'Smietanski'),
#  (['Alan', 'Floria'], 'Floria'),
#  (['Alan', 'G.', 'Blatnikoff'], 'Blatnikoff'),
#  (['Alan', 'G.', 'Greenberg'], 'Greenberg'),
#  (['Alan', 'Ginsberg'], 'Ginsberg'),
#  (['Alan', 'Graham', 'Greer'], 'Greer'),
#  (['Alan', 'H', 'Greenberg'], 'Greenberg'),
#  (['Alan', 'H.', 'Barbanel'], 'Barbanel'),
#  (['Alan', 'Hunt'], 'Hunt'),
#  (['Alan', 'I.', 'Schimmel'], 'Schimmel'),
#  (['Alan', 'J', 'Markman'], 'Markman'),
#  (['Alan', 'J', 'Ominsky'], 'Ominsky'),
#  (['Alan', 'J.', 'Baldwin'], 'Baldwin'),
#  (['Alan', 'J.', 'Belsky'], 'Belsky'),
#  (['Alan', 'J.', 'Booth,', 'Esq.'], 'Booth'),
#  (['Alan', 'J.', 'Cohen'], 'Cohen'),
#  (['Alan', 'J.', 'Golden'], 'Golden'),
#  (['Alan', 'J.', 'Konigsberg'], 'Konigsberg'),
#  (['Alan', 'J.', 'Nuta'], 'Nuta'),
#  (['Alan', 'J.', 'Statman'], 'Statman'),
#  (['Alan', 'Jay', 'Braverman'], 'Braverman'),
#  (['Alan', 'Jay', 'Foxman'], 'Foxman'),
#  (['Alan', 'Jay', 'Lander'], 'Lander'),
#  (['Alan', 'Jay', 'Lerner'], 'Lerner'),
#  (['Alan', 'Jermaine', 'Stratton'], 'Stratton'),
#  (['Alan', 'K.', 'Foe'], 'Foe'),
#  (['Alan', 'Kansas'], 'Kansas'),
#  (['Alan', 'Kolod'], 'Kolod'),
#  (['Alan', 'Kreshtool'], 'Kreshtool'),
#  (['Alan', 'L', 'Mealy'], 'Mealy'),
#  (['Alan', 'L.', 'Joseph'], 'Joseph'),
#  (['Alan', 'L.', 'Newman'], 'Newman'),
#  (['Alan', 'L.', 'Schwalbe'], 'Schwalbe'),
#  (['Alan', 'L.', 'Sirkin'], 'Sirkin'),
#  (['Alan', 'L.', 'Whitted'], 'Whitted'),
#  (['Alan', 'M', 'Kraut'], 'Kraut'),
#  (['Alan', 'M', 'Tanenbaum'], 'Tanenbaum'),
#  (['Alan', 'M', 'Tepper'], 'Tepper'),
#  (['Alan', 'M.', 'Greenberg'], 'Greenberg'),
#  (['Alan', 'M.', 'Purdie'], 'Purdie'),
#  (['Alan', 'M.', 'Salkow'], 'Salkow'),
#  (['Alan', 'M.', 'Wolinsky'], 'Wolinsky'),
#  (['Alan', 'Michael', 'Foody'], 'Foody'),
#  (['Alan', 'Molina'], 'Molina'),
#  (['Alan', 'Molina'], 'Molina'),
#  (['Alan', 'P.', 'Bayham', 'Jr.'], 'Bayham'),
#  (['Alan', 'P.', 'Dove'], 'Dove'),
#  (['Alan', 'Patrick', 'Taylor'], 'Taylor'),
#  (['Alan', 'Pearlman'], 'Pearlman'),
#  (['Alan', 'R', 'Davis'], 'Davis'),
#  (['Alan', 'R.', 'Beard'], 'Beard'),
#  (['Alan', 'R.', 'Cochran'], 'Cochran'),
#  (['Alan', 'R.', 'Goodman'], 'Goodman'),
#  (['Alan', 'R.', 'Lebowitz'], 'Lebowitz'),
#  (['Alan', 'R.', 'LeCours'], 'LeCours'),
#  (['Alan', 'R.', 'Levy'], 'Levy'),
#  (['Alan', 'R.', 'Pfaff'], 'Pfaff'),
#  (['Alan', 'Robert', 'Kolodny'], 'Kolodny'),
#  (['Alan', 'Roberts'], 'Roberts'),
#  (['Alan', 'Rosenberg'], 'Rosenberg'),
#  (['Alan', 'S.', 'Baum'], 'Baum'),
#  (['Alan', 'S.', 'Dambrov'], 'Dambrov'),
#  (['Alan', 'S.', 'Friedman'], 'Friedman'),
#  (['Alan', 'S.', 'Funk'], 'Funk'),
#  (['Alan', 'S.', 'Gold'], 'Gold'),
#  (['Alan', 'S.', 'Levine,', 'Esq.'], 'Levine'),
#  (['Alan', 'S.', 'Pierce'], 'Pierce'),
#  (['Alan', 'Scott', 'Miller'], 'Miller'),
#  (['Alan', 'Scott', 'Pickel'], 'Pickel'),
#  (['Alan', 'Silko'], 'Silko'),
#  (['Alan', 'Starker'], 'Starker'),
#  (['Alan', 'Stegall'], 'Stegall'),
#  (['Alan', 'Steven', 'Rubin'], 'Rubin'),
#  (['Alan', 'Sylvester'], 'Sylvester'),
#  (['Alan', 'V.', 'Johnson'], 'Johnson'),
#  (['Alan', 'W.', 'Cohn'], 'Cohn'),
#  (['Alan', 'Wagner'], 'Wagner'),
#  (['Alan', 'Y.', 'Medvin'], 'Medvin'),
#  (['Alana', 'Blatt', 'Clements'], 'Clements'),
#  (['Alaric', 'A.', 'Henry'], 'Henry'),
#  (['Alban', 'Dunisha'], 'Dunisha'),
#  (['Albert', 'A.', 'Biel', 'Jr.'], 'Biel'),
#  (['Albert', 'A.', 'Wolf'], 'Wolf'),
#  (['Albert', 'Aaron'], 'Aaron'),
#  (['Albert', 'Andre', 'Mitchell'], 'Mitchell'),
#  (['Albert', 'Dragon'], 'Dragon'),
#  (['Albert', 'E.', 'Davies'], 'Davies'),
#  (['Albert', 'E.', 'Desrosiers'], 'Desrosiers'),
#  (['Albert', 'E.', 'Fershing'], 'Fershing'),
#  (['Albert', 'E.', 'Hollan'], 'Hollan'),
#  (['Albert', 'E.', 'Jones'], 'Jones'),
#  (['Albert', 'E.', 'Moon'], 'Moon'),
#  (['Albert', 'E.', 'Ranum'], 'Ranum'),
#  (['Albert', 'F.', 'Maier', 'Jr.'], 'Maier'),
#  (['Albert', 'F.', 'Ries'], 'Ries'),
#  (['Albert', 'F.', 'Shamash'], 'Shamash'),
#  (['Albert', 'Farrah'], 'Farrah'),
#  (['Albert', 'G.', 'Hubby', 'III'], 'Hubby'),
#  (['Albert', 'Guadagno'], 'Guadagno'),
#  (['Albert', 'J', 'Rescinio'], 'Rescinio'),
#  (['Albert', 'J', 'Sreter'], 'Sreter'),
#  (['Albert', 'J.', 'Bannon'], 'Bannon'),
#  (['Albert', 'J.', 'DeCusati'], 'DeCusati'),
#  (['Albert', 'J.', 'Fiorella'], 'Fiorella'),
#  (['Albert', 'J.', 'Slap'], 'Slap'),
#  (['Albert', 'Joseph', 'Bolet', 'III'], 'Bolet'),
#  (['Albert', 'L.', 'Saslow'], 'Saslow'),
#  (['Albert', 'L.', 'Wheeler', 'III'], 'Wheeler'),
#  (['Albert', 'M.', 'Messer'], 'Messer'),
#  (['Albert', 'M.', 'Pearson', 'III'], 'Pearson'),
#  (['Albert', 'N.', 'Thiel', 'Jr.'], 'Thiel'),
#  (['Albert', 'R.', 'Matthews'], 'Matthews'),
#  (['Albert', 'S', 'Lazarus'], 'Lazarus'),
#  (['Albert', 'Salvi'], 'Salvi'),
#  (['Albert', 'T.', 'Van', 'Huff'], 'Huff'),
#  (['Albert', 'W.', 'Chianese,', 'Esq.'], 'Chianese'),
#  (['Albert', 'W.', 'Cornachio', 'III,', 'Esq.'], 'Cornachio'),
#  (['Albert', 'Wesley', 'Miller', 'III'], 'Miller'),
#  (['Alberto', 'Berrones'], 'Berrones'),
#  (['Alberto', 'Franco'], 'Franco'),
#  (['Alberto', 'Guadagno'], 'Guadagno'),
#  (['Alberto', 'Virgen'], 'Virgen'),
#  (['Alden', 'C.', 'Harrington'], 'Harrington'),
#  (['Aldo', 'Beltrano'], 'Beltrano'),
#  (['Aldo', 'J.', 'Stolte'], 'Stolte'),
#  (['Alec', 'Hanus'], 'Hanus'),
#  (['Alec', 'Wisner'], 'Wisner'),
#  (['Alecia', 'Elston'], 'Elston'),
#  (['Alejandro', 'David', 'Szwarcsztejn'], 'Szwarcsztejn'),
#  (['Alejandro', 'Fiol'], 'Fiol'),
#  (['Alejandro', 'J.', 'Rodriguez'], 'Rodriguez'),
#  (['Alesia', 'H.', 'Days,', 'Esq.'], 'Days'),
#  (['Alesia', 'R.', 'Strand'], 'Strand'),
#  (['Alessandro', 'F.', 'Marra,', 'Esq.'], 'Marra'),
#  (['Alessandro', 'Giribaldi'], 'Giribaldi'),
#  (['Alex', 'A.', 'Lauricella'], 'Lauricella'),
#  (['Alex', 'A.', 'Omrani,', 'Esq.'], 'Omrani'),
#  (['Alex', 'B', 'Scheingross'], 'Scheingross'),
#  (['Alex', 'Brian', 'Wallach'], 'Wallach'),
#  (['Alex', 'C.', 'Dunn'], 'Dunn'),
#  (['Alex', 'C.', 'Elder'], 'Elder'),
#  (['Alex', 'D.', 'Chapman', 'Jr.'], 'Chapman'),
#  (['Alex', 'D.', 'Cheng'], 'Cheng'),
#  (['Alex', 'F', 'Philippone'], 'Philippone'),
#  (['Alex', 'Ghibaudo'], 'Ghibaudo'),
#  (['Alex', 'Goldberg'], 'Goldberg'),
#  (['Alex', 'H.', 'Sitz', 'III'], 'Sitz'),
#  (['Alex', 'Hanna,', 'Esq.'], 'Hanna'),
#  (['Alex', 'J.', 'Miller'], 'Miller'),
#  (['Alex', 'J.', 'Remick'], 'Remick'),
#  (['Alex', 'N.', 'Kapetan'], 'Kapetan'),
#  (['Alex', 'Rabin'], 'Rabin'),
#  (['Alex', 'S.', 'Friedland'], 'Friedland'),
#  (['Alex', 'Thomas', 'Postic'], 'Postic'),
#  (['Alex', 'W.', 'Nocerino'], 'Nocerino'),
#  (['Alex', 'W.', 'Russell,', 'J.D.,', 'C.P.A.'], 'Russell'),
#  (['Alex', 'Wyatt', 'Wright'], 'Wright'),
#  (['Alexa', 'D', 'Amato', 'Barrera'], 'Barrera'),
#  (['Alexander', 'Begum'], 'Begum'),
#  (['Alexander', 'D.', 'Boyd'], 'Boyd'),
#  (['Alexander', 'D.', 'Crecca'], 'Crecca'),
#  (['Alexander', 'E.', 'Sklavos'], 'Sklavos'),
#  (['Alexander', 'F.', 'Reichert'], 'Reichert'),
#  (['Alexander', 'Gray', 'Hait'], 'Hait'),
#  (['Alexander', 'Gregory', 'Rozman'], 'Rozman'),
#  (['Alexander', 'J.', 'Gordon'], 'Gordon'),
#  (['Alexander', 'J.', 'Jamiolkowski'], 'Jamiolkowski'),
#  (['Alexander', 'J.', 'Kemeny'], 'Kemeny'),
#  (['Alexander', 'J.', 'Smith'], 'Smith'),
#  (['Alexander', 'James', 'Ginsburg'], 'Ginsburg'),
#  (['Alexander', 'Joseph', 'Alfano'], 'Alfano'),
#  (['Alexander', 'K.', 'Davison'], 'Davison'),
#  (['Alexander', 'Karasik'], 'Karasik'),
#  (['Alexander', 'Latanision'], 'Latanision'),
#  (['Alexander', 'Levine,', 'Esq.'], 'Levine'),
#  (['Alexander', 'Louis', 'Silow'], 'Silow'),
#  (['Alexander', 'Lumelsky'], 'Lumelsky'),
#  (['Alexander', 'M.', 'Dashe'], 'Dashe'),
#  (['Alexander', 'Mark', 'Weinberg'], 'Weinberg'),
#  (['Alexander', 'N', 'Levay', 'Jr.'], 'Levay'),
#  (['Alexander', 'R', 'Cain'], 'Cain'),
#  (['Alexander', 'S.', 'Kammer'], 'Kammer'),
#  (['Alexander', 'Simanovsky'], 'Simanovsky'),
#  (['Alexandra', 'Erna', 'Mora'], 'Mora'),
#  (['Alexandra', 'Hull'], 'Hull'),
#  (['Alexandra', 'J.', 'Schultz'], 'Schultz'),
#  (['Alexandre', 'E.', 'Bonin'], 'Bonin'),
#  (['Alexia', 'Pittas-Giroux'], 'Pittas-Giroux'),
#  (['Alexis', 'A.', 'Langella'], 'Langella'),
#  (['Alexis', 'S.', 'Mullaney'], 'Mullaney'),
#  (['Alf', 'E.', 'Sivertson'], 'Sivertson'),
#  (['Alf', 'R.', 'H.', 'R.', 'Langan'], 'Langan'),
#  (['Alford', 'Haselden'], 'Haselden'),
#  (['Alfred', 'A', 'Levingston'], 'Levingston'),
#  (['Alfred', 'A', 'Veltri'], 'Veltri'),
#  (['Alfred', 'B.', 'Castillo', 'Jr.'], 'Castillo'),
#  (['Alfred', 'B.', 'Mencuccini'], 'Mencuccini'),
#  (['Alfred', 'C.', 'Laub'], 'Laub'),
#  (['Alfred', 'E.', 'Marotta'], 'Marotta'),
#  (['Alfred', 'G.', 'Howell'], 'Howell'),
#  (['Alfred', 'H.', 'Chan'], 'Chan'),
#  (['Alfred', 'J', 'Verderose'], 'Verderose'),
#  (['Alfred', 'Jackson', 'Powell', 'Jr.'], 'Powell'),
#  (['Alfred', 'L.', 'Allgood'], 'Allgood'),
#  (['Alfred', 'M.', 'Anthony'], 'Anthony'),
#  (['Alfred', 'M.', 'Fazio'], 'Fazio'),
#  (['Alfred', 'N.', 'Corriere'], 'Corriere'),
#  (['Alfred', 'Paniccia', 'Jr.'], 'Paniccia'),
#  (['Alfred', 'Paul', 'Denowitz'], 'Denowitz'),
#  (['Alfred', 'R.', 'Beresko'], 'Beresko'),
#  (['Alfred', 'R.', 'Keep'], 'Keep'),
#  (['Alfred', 'T', 'McGill'], 'McGill'),
#  (['Alfred', 'V.', 'Altopiedi'], 'Altopiedi'),
#  (['Alfred', 'V.', 'Gellene,', 'Esq.'], 'Gellene'),
#  (['Alfredo', 'G.', 'Evangelista'], 'Evangelista'),
#  (['Ali', 'Hakeem'], 'Hakeem'),
#  (['Ali', 'Stephen', 'Ramadan'], 'Ramadan'),
#  (['Alice', 'A.', 'Buffington'], 'Buffington'),
#  (['Alice', 'A.', 'Malleris'], 'Malleris'),
#  (['Alice', 'K', 'Mansfield'], 'Mansfield'),
#  (['Alice', 'M', 'Beasley'], 'Beasley'),
#  (['Alice', 'Oppenheim', 'London'], 'London'),
#  (['Alice', 'Rodriguez'], 'Rodriguez'),
#  (['Alicia', 'C.', 'Freeze,', 'Esq.'], 'Freeze'),
#  (['Alicia', 'P.', 'Chalumeau,', 'Esq.'], 'Chalumeau'),
#  (['Alicia', 'Sarah', 'Curran'], 'Curran'),
#  (['Aline', 'O.', 'Marcantonio'], 'Marcantonio'),
#  (['Alisa', 'E.', 'George'], 'George'),
#  (['Alisa', 'L.', 'Silverstein', 'Fermaglich'], 'Fermaglich'),
#  (['Alison', 'Courtney', 'Wells'], 'Wells'),
#  (['Alison', 'Hershewe'], 'Hershewe'),
#  (['Alison', 'S.', 'Gokal'], 'Gokal'),
#  (['Alison', 'Shontz', 'Franklin'], 'Franklin'),
#  (['Alison', 'White', 'Haynes'], 'Haynes'),
#  (['Alison', 'Whitney', 'Talbert'], 'Talbert'),
#  (['Alison', 'Wholey', 'Briggs,', 'RN,', 'Esq.'], 'Briggs'),
#  (['Alissa', 'Joy', 'Wool,', 'Esq.'], 'Wool'),
#  (['Alissa', 'Sammarco', 'Magenheim'], 'Magenheim'),
#  (['Alistair', 'Andrew', 'Adkinson'], 'Adkinson'),
#  (['Alister', 'Wong'], 'Wong'),
#  (['Alivia', 'Kassab', 'Arabo'], 'Arabo'),
#  (['Alix', 'Duroseau', 'Jr.'], 'Duroseau'),
#  (['Alix', 'H', 'Sanders'], 'Sanders'),
#  (['Allain', 'F.', 'Hardin'], 'Hardin'),
#  (['Allan', 'Berger'], 'Berger'),
#  (['Allan', 'C.', 'Breslin'], 'Breslin'),
#  (['Allan', 'C.', 'Orsborn'], 'Orsborn'),
#  (['Allan', 'C.', 'Perry'], 'Perry'),
#  (['Allan', 'Charles', 'VanDeMark'], 'VanDeMark'),
#  (['Allan', 'Curry'], 'Curry'),
#  (['Allan', 'D.', 'Goldstein'], 'Goldstein'),
#  (['Allan', 'E.', 'Levin'], 'Levin'),
#  (['Allan', 'F.', 'Davis'], 'Davis'),
#  (['Allan', 'F.', 'Shapiro'], 'Shapiro'),
#  (['Allan', 'H', 'Rombro'], 'Rombro'),
#  (['Allan', 'H.', 'Bell'], 'Bell'),
#  (['Allan', 'H.', 'Kalish'], 'Kalish'),
#  (['Allan', 'I', 'Kornblau'], 'Kornblau'),
#  (['Allan', 'J.', 'Ray'], 'Ray'),
#  (['Allan', 'J.', 'Sagot'], 'Sagot'),
#  (['Allan', 'Jaffe'], 'Jaffe'),
#  (['Allan', 'K', 'Plimack'], 'Plimack'),
#  (['Allan', 'L.', 'MacDougall'], 'MacDougall'),
#  (['Allan', 'L.', 'Potter'], 'Potter'),
#  (['Allan', 'M.', 'Lewis'], 'Lewis'),
#  (['Allan', 'P', 'Cramer'], 'Cramer'),
#  (['Allan', 'P.', 'White'], 'White'),
#  (['Allan', 'R.', 'Chason'], 'Chason'),
#  (['Allan', 'Studenberg'], 'Studenberg'),
#  (['Allan', 'T', 'Downen'], 'Downen'),
#  (['Allegra', 'Carpenter'], 'Carpenter'),
#  (['Allen', 'C.', 'Engerman'], 'Engerman'),
#  (['Allen', 'C.', 'Jones'], 'Jones'),
#  (['Allen', 'C.', 'Speare'], 'Speare'),
#  (['Allen', 'D', 'Kincannon'], 'Kincannon'),
#  (['Allen', 'D', 'Place', 'Jr.'], 'Place'),
#  (['Allen', 'D.', 'Glazer'], 'Glazer'),
#  (['Allen', 'E.', 'Ertel'], 'Ertel'),
#  (['Allen', 'E.', 'Moss'], 'Moss'),
#  (['Allen', 'Finley', 'Schuldenfrei'], 'Schuldenfrei'),
#  (['Allen', 'J', 'Kwawer'], 'Kwawer'),
#  (['Allen', 'J.', 'Rosner'], 'Rosner'),
#  (['Allen', 'K.', 'Brown'], 'Brown'),
#  (['Allen', 'L.', 'Fugate'], 'Fugate'),
#  (['Allen', 'M.', 'Wolf'], 'Wolf'),
#  (['Allen', 'Mark', 'Stewart'], 'Stewart'),
#  (['Allen', 'Mills'], 'Mills'),
#  (['Allen', 'Paul', 'Allweiss'], 'Allweiss'),
#  (['Allen', 'R.', 'Ball'], 'Ball'),
#  (['Allen', 'R.', 'Desmond', 'Jr.'], 'Desmond'),
#  (['Allen', 'R.', 'Prunty'], 'Prunty'),
#  (['Allen', 'R.', 'Weed'], 'Weed'),
#  (['Allen', 'Richard', 'Seaman'], 'Seaman'),
#  (['Allen', 'S.', 'Gabe'], 'Gabe'),
#  (['Allen', 'Tittle'], 'Tittle'),
#  (['Allen', 'V.', 'Davis'], 'Davis'),
#  (['Allen', 'W.', 'Lindsay', 'Jr.'], 'Lindsay'),
#  (['Allen', 'William', 'Martincavage'], 'Martincavage'),
#  (['Allette', 'B.', 'Williams'], 'Williams'),
#  (['Allison', 'B.', 'Fagerman'], 'Fagerman'),
#  (['Allison', 'B.', 'Lane'], 'Lane'),
#  (['Allison', 'B.', 'Walsh'], 'Walsh'),
#  (['Allison', 'Doliner', 'Hockman'], 'Hockman'),
#  (['Allison', 'E.', 'McKenzie'], 'McKenzie'),
#  (['Allison', 'Gilman,', 'Esq.'], 'Gilman'),
#  (['Allison', 'Hymel'], 'Hymel'),
#  (['Allison', 'L.', 'Lampert,', 'Esq.'], 'Lampert'),
#  (['Allison', 'Luck', 'Bridges'], 'Bridges'),
#  (['Allison', 'M.', 'Kinnier'], 'Kinnier'),
#  (['Allison', 'Schreiber', 'Lee'], 'Lee'),
#  (['Allison', 'Y.', 'Beauparlant'], 'Beauparlant'),
#  (['Allyson', 'Rowe'], 'Rowe'),
#  (['Alma', 'C.', 'Defillo-Millman'], 'Defillo-Millman'),
#  (['Almis', 'Joseph', 'Stempuzis'], 'Stempuzis'),
#  (['Alok', 'A.', 'Kale'], 'Kale'),
#  (['Alphonso', 'Stafford', 'Hearns', 'Jr.'], 'Hearns'),
#  (['Altagracia', 'Nunez'], 'Nunez'),
#  (['Altom', 'M.', 'Maglio,', 'Esq.'], 'Maglio'),
#  (['Alton', 'B.', 'Prillaman'], 'Prillaman'),
#  (['Alton', 'C.', 'Hale', 'Jr.'], 'Hale'),
#  (['Alton', 'C.', 'Haynes'], 'Haynes'),
#  (['Alton', 'J.', 'Smith'], 'Smith'),
#  (['Alton', 'Russell', 'Watson'], 'Watson'),
#  (['Alvand', 'Ali', 'Mokhtari'], 'Mokhtari'),
#  (['Alvarene', 'Nethola', 'Owens'], 'Owens'),
#  (['Alvaro', 'Francisco', 'Areces'], 'Areces'),
#  (['Alvin', 'C.', 'Knight'], 'Knight'),
#  (['Alvin', 'David', 'Hersh'], 'Hersh'),
#  (['Alvin', 'Dorfman'], 'Dorfman'),
#  (['Alvin', 'F.', 'de', 'Levie'], 'Levie'),
#  (['Alvin', 'Grady', 'Wells', 'Jr.'], 'Wells'),
#  (['Alvin', 'J.', 'Ziontz'], 'Ziontz'),
#  (['Alvin', 'Lee', 'Peters'], 'Peters'),
#  (['Alvin', 'O.', 'Boucher'], 'Boucher'),
#  (['Alvin', 'S.', 'Nathanson'], 'Nathanson'),
#  (['Alvin', 'Wellington', 'Barlow'], 'Barlow'),
#  (['Alwyn', 'Luckey'], 'Luckey'),
#  (['Alyse', 'S.', 'Richard'], 'Richard'),
#  (['Alyson', 'Dotson'], 'Dotson'),
#  (['Alyson', 'M.', 'Sullivan'], 'Sullivan'),
#  (['Alyssa', 'D.', 'Phillips'], 'Phillips'),
#  (['Alyssa', 'F.', 'Bomze'], 'Bomze'),
#  (['Alyssa', 'Kusturiss', 'Poole'], 'Poole'),
#  (['Alyssa', 'S.', 'Pershan'], 'Pershan'),
#  (['Amala', 'Nath'], 'Nath'),
#  (['Amalia', 'Skogen', 'Lucero,', 'Esq.'], 'Lucero'),
#  (['Aman', 'N.', 'Shah'], 'Shah'),
#  (['Amanda', 'A.', 'Mingo'], 'Mingo'),
#  (['Amanda', 'Bowden', 'Houser'], 'Houser'),
#  (['Amanda', 'C.', 'Musselwhite'], 'Musselwhite'),
#  (['Amanda', 'H.', 'Yenerall'], 'Yenerall'),
#  (['Amanda', 'J.', 'Davis'], 'Davis'),
#  (['Amanda', 'L.', 'Darby'], 'Darby'),
#  (['Amanda', 'L.', 'Paye'], 'Paye'),
#  (['Amanda', 'L.', 'Sanders'], 'Sanders'),
#  (['Amanda', 'L.H.', 'Brinton'], 'Brinton'),
#  (['Amanda', 'Lowerre', 'O', 'Donnell'], 'Donnell'),
#  (['Amanda', 'Lynn', 'Hinshaw'], 'Hinshaw'),
#  (['Amanda', 'M.', 'Burke'], 'Burke'),
#  (['Amanda', 'M.', 'Como,', 'Esq.'], 'Como'),
#  (['Amanda', 'M.', 'Furth'], 'Furth'),
#  (['Amanda', 'M.', 'Gehring'], 'Gehring'),
#  (['Amanda', 'M.', 'Morris'], 'Morris'),
#  (['Amanda', 'Page', 'Wills'], 'Wills'),
#  (['Amanda', 'R.', 'Stern'], 'Stern'),
#  (['Amanda', 'Racine', 'Stevens'], 'Stevens'),
#  (['Amanda', 'Reiter'], 'Reiter'),
#  (['Amanda', 'Soyoung', 'Chang'], 'Chang'),
#  (['Amanda', 'Vina', 'Green,', 'Esq.'], 'Green'),
#  (['Amanda', 'Zafur'], 'Zafur'),
#  (['Amar', 'Sanghera', 'Weisman'], 'Weisman'),
#  (['Amarante', 'M.', 'Carvalho'], 'Carvalho'),
#  (['Ambar', 'Bhargava'], 'Bhargava'),
#  (['Amber', 'C.', 'Winer-Gebhart'], 'Winer-Gebhart'),
#  (['Amber', 'Kaimer'], 'Kaimer'),
#  (['Amber', 'Sharp', 'Pallante'], 'Pallante'),
#  (['Ameli', 'Padron-Fragetta'], 'Padron-Fragetta'),
#  (['Amelia', 'De', 'Los', 'Santos'], 'Santos'),
#  (['Americo', 'Borza'], 'Borza'),
#  (['Amiee', 'R.', 'Buckman'], 'Buckman'),
#  (['Amir', 'A.', 'Ladan'], 'Ladan'),
#  (['Amit', 'M.', 'Navare'], 'Navare'),
#  (['Ammar', 'Alo,', 'Esq.'], 'Alo'),
#  (['Amme', 'D.', 'Blair'], 'Blair'),
#  (['Amy', 'Acheson'], 'Acheson'),
#  (['Amy', 'B.', 'Goldstein'], 'Goldstein'),
#  (['Amy', 'B.', 'Vandeveld'], 'Vandeveld'),
#  (['Amy', 'Bailey', 'Quillen'], 'Quillen'),
#  (['Amy', 'C.', 'Crossan'], 'Crossan'),
#  (['Amy', 'C.', 'Thomas'], 'Thomas'),
#  (['Amy', 'C.', 'Yenari'], 'Yenari'),
#  (['Amy', 'Carol', 'Gowan'], 'Gowan'),
#  (['Amy', 'Cashore', 'Mariani'], 'Mariani'),
#  (['Amy', 'Cofield-Derrick'], 'Cofield-Derrick'),
#  (['Amy', 'Davis', 'Salladay'], 'Salladay'),
#  (['Amy', 'E.', 'Rudley'], 'Rudley'),
#  (['Amy', 'E.', 'Skelton'], 'Skelton'),
#  (['Amy', 'E.', 'Stoner'], 'Stoner'),
#  (['Amy', 'Elizabeth', 'Allred'], 'Allred'),
#  (['Amy', 'Elizabeth', 'Keiser'], 'Keiser'),
#  (['Amy', 'H.', 'Bailey'], 'Bailey'),
#  (['Amy', 'J.', 'Vesely'], 'Vesely'),
#  (['Amy', 'K.', 'Hart'], 'Hart'),
#  (['Amy', 'K.', 'Witherite'], 'Witherite'),
#  (['Amy', 'L', 'Brewer'], 'Brewer'),
#  (['Amy', 'L.', 'Gervich'], 'Gervich'),
#  (['Amy', 'L.', 'Gillette'], 'Gillette'),
#  (['Amy', 'L.', 'Insler'], 'Insler'),
#  (['Amy', 'L.', 'Mitchell'], 'Mitchell'),
#  (['Amy', 'L.', 'Patras'], 'Patras'),
#  (['Amy', 'L.', 'Sergent'], 'Sergent'),
#  (['Amy', 'L.', 'Vaudreuil'], 'Vaudreuil'),
#  (['Amy', 'Lorenz'], 'Lorenz'),
#  (['Amy', 'Lynn', 'Wille'], 'Wille'),
#  (['Amy', 'M', 'Combs'], 'Combs'),
#  (['Amy', 'M.', 'Johnston'], 'Johnston'),
#  (['Amy', 'M.', 'Keating'], 'Keating'),
#  (['Amy', 'M.', 'Orsi'], 'Orsi'),
#  (['Amy', 'Morse'], 'Morse'),
#  (['Amy', 'N.', 'Tobias,', 'Esquire'], 'Tobias'),
#  (['Amy', 'R.', 'Boring'], 'Boring'),
#  (['Amy', 'R.', 'Turos'], 'Turos'),
#  (['Amy', 'R.', 'Wheatley'], 'Wheatley'),
#  (['Amy', 'R.', 'Winsten'], 'Winsten'),
#  (['Amy', 'Rosen', 'Snell'], 'Snell'),
#  (['Amy', 'S.', 'Griggs'], 'Griggs'),
#  (['Amy', 'Smith', 'Boyer'], 'Boyer'),
#  (['Amy', 'Sue', 'Taylor'], 'Taylor'),
#  (['Amy', 'Urness'], 'Urness'),
#  (['Amy', 'Vickers', 'Fritz,', 'Esq.'], 'Fritz'),
#  (['Ana', 'Fabiola', 'Olivares'], 'Olivares'),
#  (['Ana', 'Laura', 'Gutierrez'], 'Gutierrez'),
#  (['Ana', 'Luisa', 'Molleda'], 'Molleda'),
#  (['Ana', 'M.', 'Aparicio'], 'Aparicio'),
#  (['Ana', 'M.', 'Sulit', 'Schmidt'], 'Schmidt'),
#  (['Ana', 'Maria', 'McNamara'], 'McNamara'),
#  (['Ana', 'Maria', 'Sardi'], 'Sardi'),
#  (['Ana', 'T.', 'Jacobs'], 'Jacobs'),
#  (['Analisa', 'Sondergaard'], 'Sondergaard'),
#  (['Anand', 'Narain', 'Misra'], 'Misra'),
#  (['Anat', 'Gordon'], 'Gordon'),
#  (['Anatta', 'Levinsky'], 'Levinsky'),
#  (['Ancil', 'L.', 'Cox', 'Jr.'], 'Cox'),
#  (['Anderson', 'E.', 'Hatfield,', 'III'], 'Hatfield'),
#  (['Anderson', 'L.', 'Washburn'], 'Washburn'),
#  (['Andis', 'Svikis'], 'Svikis'),
#  (['Andre', 'D.', 'Dorval'], 'Dorval'),
#  (['AnDre', 'D.', 'Summers'], 'Summers'),
#  (['Andre', 'Dandurand'], 'Dandurand'),
#  (['Andre', 'Fereole', 'Regard'], 'Regard'),
#  (['Andre', 'G.', 'Crenshaw'], 'Crenshaw'),
#  (['Andre', 'M.', 'Lagomarsino,', 'Esq.'], 'Lagomarsino'),
#  (['Andre', 'Michniak'], 'Michniak'),
#  (['Andre', 'T.', 'Young,', 'Esq.'], 'Young'),
#  (['Andrea', 'Amodeo-Vickery'], 'Amodeo-Vickery'),
#  (['Andrea', 'Anderson'], 'Anderson'),
#  (['Andrea', 'Caro'], 'Caro'),
#  (['Andrea', 'Dianne', 'McMillan'], 'McMillan'),
#  (['Andrea', 'E.', 'Miller'], 'Miller'),
#  (['Andrea', 'E.', 'Watters'], 'Watters'),
#  (['Andrea', 'G.', 'Green'], 'Green'),
#  (['Andrea', 'Huston'], 'Huston'),
#  (['Andrea', 'J', 'Baron'], 'Baron'),
#  (['Andrea', 'K', 'Sugar'], 'Sugar'),
#  (['Andrea', 'L.', 'Ciobanu'], 'Ciobanu'),
#  (['Andrea', 'L.', 'Heckler'], 'Heckler'),
#  (['Andrea', 'L.', 'Pawlak'], 'Pawlak'),
#  (['Andrea', 'L.', 'Shapiro,', 'Esq.'], 'Shapiro'),
#  (['Andrea', 'Rae', 'Henson'], 'Henson'),
#  (['Andrea', 'Ruth', 'Bateman'], 'Bateman'),
#  (['Andrea', 'T', 'Carty'], 'Carty'),
#  (['Andrea', 'Winder'], 'Winder'),
#  (['Andres', 'Alonso'], 'Alonso'),
#  (['Andres', 'Eduardo', 'Almanzan'], 'Almanzan'),
#  (['Andres', 'Gutierrez', 'De', 'Cos'], 'Cos'),
#  (['Andres', 'M.', 'Aranda'], 'Aranda'),
#  (['Andrew', 'A', 'Dunlap'], 'Dunlap'),
#  (['Andrew', 'A', 'Szakaly', 'Jr.'], 'Szakaly'),
#  (['Andrew', 'A.', 'Agard'], 'Agard'),
#  (['Andrew', 'A.', 'Artus'], 'Artus'),
#  (['Andrew', 'A.', 'Ballerini'], 'Ballerini'),
#  (['Andrew', 'A.', 'Cohen'], 'Cohen'),
#  (['Andrew', 'A.', 'Iacobelli'], 'Iacobelli'),
#  (['Andrew', 'A.', 'Kimler'], 'Kimler'),
#  (['Andrew', 'A.', 'Lemmon'], 'Lemmon'),
#  (['Andrew', 'A.', 'Prolman'], 'Prolman'),
#  (['Andrew', 'A.', 'Smith'], 'Smith'),
#  (['Andrew', 'A.', 'Solomon'], 'Solomon'),
#  (['Andrew', 'Ausband'], 'Ausband'),
#  (['Andrew', 'B.', 'Ezell'], 'Ezell'),
#  (['Andrew', 'B.', 'Farley'], 'Farley'),
#  (['Andrew', 'B.', 'Miller'], 'Miller'),
#  (['Andrew', 'B.', 'Protzman'], 'Protzman'),
#  (['Andrew', 'B.', 'Smith,', 'Esq.'], 'Smith'),
#  (['Andrew', 'B.', 'Sommerman'], 'Sommerman'),
#  (['Andrew', 'B.', 'Spiegel'], 'Spiegel'),
#  (['Andrew', 'Bakos'], 'Bakos'),
#  (['Andrew', 'Bayer'], 'Bayer'),
#  (['Andrew', 'Beal'], 'Beal'),
#  (['Andrew', 'Bersin'], 'Bersin'),
#  (['Andrew', 'C', 'Clifford'], 'Clifford'),
#  (['Andrew', 'C.', 'Barr'], 'Barr'),
#  (['Andrew', 'C.', 'Burrell'], 'Burrell'),
#  (['Andrew', 'C.', 'Clarke'], 'Clarke'),
#  (['Andrew', 'C.', 'Eckert'], 'Eckert'),
#  (['Andrew', 'C.', 'Johnson'], 'Johnson'),
#  (['Andrew', 'C.', 'Schnack', 'III.'], 'Schnack'),
#  (['Andrew', 'C.', 'Skinner'], 'Skinner'),
#  (['Andrew', 'Chafin'], 'Chafin'),
#  (['Andrew', 'Charles', 'Lease'], 'Lease'),
#  (['Andrew', 'Clark', 'Stebbins'], 'Stebbins'),
#  (['Andrew', 'D', 'Grimes'], 'Grimes'),
#  (['Andrew', 'D.', 'Glasgrow'], 'Glasgrow'),
#  (['Andrew', 'D.', 'Huppert'], 'Huppert'),
#  (['Andrew', 'D.', 'Jones'], 'Jones'),
#  (['Andrew', 'D.', 'Presberg'], 'Presberg'),
#  (['Andrew', 'D.', 'Sabetta'], 'Sabetta'),
#  (['Andrew', 'D.', 'Stone,', 'Esq.'], 'Stone'),
#  (['Andrew', 'D.', 'Swain'], 'Swain'),
#  (['Andrew', 'D.', 'Tabenkin'], 'Tabenkin'),
#  (['Andrew', 'E.', 'Greenwald'], 'Greenwald'),
#  (['Andrew', 'E.', 'Karim'], 'Karim'),
#  (['Andrew', 'Edward', 'Feske'], 'Feske'),
#  (['Andrew', 'F.', 'Garruto'], 'Garruto'),
#  (['Andrew', 'F.', 'Russo'], 'Russo'),
#  (['Andrew', 'F.', 'Stasio', 'Jr.'], 'Stasio'),
#  (['Andrew', 'Fulkerson'], 'Fulkerson'),
#  (['Andrew', 'G', 'Ramon'], 'Ramon'),
#  (['Andrew', 'G.', 'Schrader'], 'Schrader'),
#  (['Andrew', 'G.', 'Storie'], 'Storie'),
#  (['Andrew', 'H', 'P', 'Norton'], 'Norton'),
#  (['Andrew', 'H.', 'Agatston'], 'Agatston'),
#  (['Andrew', 'H.', 'Haas'], 'Haas'),
#  (['Andrew', 'H.', 'Marty'], 'Marty'),
#  (['Andrew', 'H.', 'Quinn'], 'Quinn'),
#  (['Andrew', 'H.', 'Wood'], 'Wood'),
#  (['Andrew', 'Harakas'], 'Harakas'),
#  (['Andrew', 'Harry', 'Drucker'], 'Drucker'),
#  (['Andrew', 'Hoverman'], 'Hoverman'),
#  (['Andrew', 'I.', 'Hamelsky'], 'Hamelsky'),
#  (['Andrew', 'J', 'Renda', 'Jr.'], 'Renda'),
#  (['Andrew', 'J.', 'Bainbridge'], 'Bainbridge'),
#  (['Andrew', 'J.', 'Brown'], 'Brown'),
#  (['Andrew', 'J.', 'Cafiero'], 'Cafiero'),
#  (['Andrew', 'J.', 'Gibbs'], 'Gibbs'),
#  (['Andrew', 'J.', 'Gibbs'], 'Gibbs'),
#  (['Andrew', 'J.', 'Kinstler'], 'Kinstler'),
#  (['Andrew', 'J.', 'Kutsulis', 'Jr.'], 'Kutsulis'),
#  (['Andrew', 'J.', 'Mallon'], 'Mallon'),
#  (['Andrew', 'J.', 'McCumber'], 'McCumber'),
#  (['Andrew', 'J.', 'Morrissey'], 'Morrissey'),
#  (['Andrew', 'J.', 'O', 'Keefe'], 'Keefe'),
#  (['Andrew', 'J.', 'Reinhardt'], 'Reinhardt'),
#  (['Andrew', 'J.', 'Rodnite', 'Jr.'], 'Rodnite'),
#  (['Andrew', 'J.', 'Rossetti,', 'Esq.'], 'Rossetti'),
#  (['Andrew', 'J.', 'Schatkin'], 'Schatkin'),
#  (['Andrew', 'J.', 'Smithart', 'III'], 'Smithart'),
#  (['Andrew', 'J.', 'Thompson'], 'Thompson'),
#  (['Andrew', 'Jacobs'], 'Jacobs'),
#  (['Andrew', 'James', 'Peters'], 'Peters'),
#  (['Andrew', 'John', 'Calcagno'], 'Calcagno'),
#  (['Andrew', 'Johnson'], 'Johnson'),
#  (['Andrew', 'K.', 'Jacoby'], 'Jacoby'),
#  (['Andrew', 'Kossover,', 'Esq.'], 'Kossover'),
#  (['Andrew', 'L.', 'Drapkin'], 'Drapkin'),
#  (['Andrew', 'L.', 'Ellenberg'], 'Ellenberg'),
#  (['Andrew', 'L.', 'Miller,', 'Esq.'], 'Miller'),
#  (['Andrew', 'L.', 'Shapiro'], 'Shapiro'),
#  (['Andrew', 'Laplante'], 'Laplante'),
#  (['Andrew', 'Lawrence', 'Statmore'], 'Statmore'),
#  (['Andrew', 'M', 'Liefer'], 'Liefer'),
#  (['Andrew', 'M', 'Tillem'], 'Tillem'),
#  (['Andrew', 'M.', 'Abraham'], 'Abraham'),
#  (['Andrew', 'M.', 'Barker'], 'Barker'),
#  (['Andrew', 'M.', 'Carroll'], 'Carroll'),
#  (['Andrew', 'M.', 'Casey'], 'Casey'),
#  (['Andrew', 'M.', 'Friedman'], 'Friedman'),
#  (['Andrew', 'M.', 'Korduba'], 'Korduba'),
#  (['Andrew', 'M.', 'Kulick'], 'Kulick'),
#  (['Andrew', 'M.', 'Laskin'], 'Laskin'),
#  (['Andrew', 'M.', 'Newcomb'], 'Newcomb'),
#  (['Andrew', 'M.', 'Rockman'], 'Rockman'),
#  (['Andrew', 'M.', 'Romano'], 'Romano'),
#  (['Andrew', 'M.', 'Wubbenhorst,', 'Esq.'], 'Wubbenhorst'),
#  (['Andrew', 'M.', 'Yoder'], 'Yoder'),
#  (['Andrew', 'Mark', 'Skier'], 'Skier'),
#  (['Andrew', 'McGee'], 'McGee'),
#  (['Andrew', 'Michael', 'Sacks'], 'Sacks'),
#  (['Andrew', 'Montroy'], 'Montroy'),
#  (['Andrew', 'Mooney,', 'Esq.'], 'Mooney'),
#  (['Andrew', 'N.', 'Cassas'], 'Cassas'),
#  (['Andrew', 'N.', 'Greher'], 'Greher'),
#  (['Andrew', 'Nestor', 'III.'], 'Nestor'),
#  (['Andrew', 'O.', 'Carrington'], 'Carrington'),
#  (['Andrew', 'Ott'], 'Ott'),
#  (['Andrew', 'P.', 'Botti'], 'Botti'),
#  (['Andrew', 'P.', 'Cioffi'], 'Cioffi'),
#  (['Andrew', 'P.', 'Mazzeo'], 'Mazzeo'),
#  (['Andrew', 'P.', 'Motel'], 'Motel'),
#  (['Andrew', 'P.', 'Walsh'], 'Walsh'),
#  (['Andrew', 'R', 'McGraw'], 'McGraw'),
#  (['Andrew', 'R.', 'Hamil'], 'Hamil'),
#  (['Andrew', 'R.', 'Kirschner'], 'Kirschner'),
#  (['Andrew', 'R.', 'Liverman'], 'Liverman'),
#  (['Andrew', 'R.', 'Louis'], 'Louis'),
#  (['Andrew', 'R.', 'Macklin'], 'Macklin'),
#  (['Andrew', 'R.', 'Pauley'], 'Pauley'),
#  (['Andrew', 'R.', 'Schwing'], 'Schwing'),
#  (['Andrew', 'R.', 'Steiker'], 'Steiker'),
#  (['Andrew', 'R.', 'Wolf'], 'Wolf'),
#  (['Andrew', 'Ralph', 'Dempster'], 'Dempster'),
#  (['Andrew', 'Rosner'], 'Rosner'),
#  (['Andrew', 'Ross', 'Mackenzie'], 'Mackenzie'),
#  (['Andrew', 'Rubin'], 'Rubin'),
#  (['Andrew', 'Ryan', 'Magdy'], 'Magdy'),
#  (['Andrew', 'S', 'Blumer'], 'Blumer'),
#  (['Andrew', 'S', 'Nason'], 'Nason'),
#  (['Andrew', 'S.', 'Abramson'], 'Abramson'),
#  (['Andrew', 'S.', 'Baker'], 'Baker'),
#  (['Andrew', 'S.', 'Caslowitz'], 'Caslowitz'),
#  (['Andrew', 'S.', 'Goldwyn'], 'Goldwyn'),
#  (['Andrew', 'S.', 'Murrie'], 'Murrie'),
#  (['Andrew', 'S.', 'Muth'], 'Muth'),
#  (['Andrew', 'S.', 'Viola'], 'Viola'),
#  (['Andrew', 'S.', 'Wainwright'], 'Wainwright'),
#  (['Andrew', 'Schwarz'], 'Schwarz'),
#  (['Andrew', 'Scott', 'Epstein'], 'Epstein'),
#  (['Andrew', 'Scott', 'Henschel'], 'Henschel'),
#  (['Andrew', 'Shaul'], 'Shaul'),
#  (['Andrew', 'Sher'], 'Sher'),
#  (['Andrew', 'Skemp'], 'Skemp'),
#  (['Andrew', 'Sky'], 'Sky'),
#  (['Andrew', 'Slepian'], 'Slepian'),
#  (['Andrew', 'Stanton', 'Garvis'], 'Garvis'),
#  (['Andrew', 'Staten', 'Adams'], 'Adams'),
#  (['Andrew', 'T.', 'Blum'], 'Blum'),
#  (['Andrew', 'T.', 'Houghton'], 'Houghton'),
#  (['Andrew', 'T.', 'Neuwirth'], 'Neuwirth'),
#  (['Andrew', 'T.', 'Richardson', 'III'], 'Richardson'),
#  (['Andrew', 'T.', 'Sheeley'], 'Sheeley'),
#  (['Andrew', 'Tarry'], 'Tarry'),
#  (['Andrew', 'W', 'Chasse'], 'Chasse'),
#  (['Andrew', 'W.', 'Bokar,', 'Esq.'], 'Bokar'),
#  (['Andrew', 'W.', 'Horn,', 'Esq.'], 'Horn'),
#  (['Andrew', 'W.', 'Jones'], 'Jones'),
#  (['Andrew', 'W.', 'Seibert'], 'Seibert'),
#  (['Andrew', 'W.', 'Siegel'], 'Siegel'),
#  (['Andrew', 'W.', 'Snyder'], 'Snyder'),
#  (['Andrew', 'W.', 'Yung'], 'Yung'),
#  (['Andrew', 'Willers'], 'Willers'),
#  (['Andrew', 'William', 'Wise'], 'Wise'),
#  (['Andrew', 'Wilson'], 'Wilson'),
#  (['Andrew', 'Wolfenson'], 'Wolfenson'),
#  (['Andrew', 'Wolff'], 'Wolff'),
#  (['Andrew', 'Y.', 'Kim'], 'Kim'),
#  (['Andrew', 'Yiangou'], 'Yiangou'),
#  (['Andrew', 'Zelman'], 'Zelman'),
#  (['Andrewe', 'W', 'Johnson'], 'Johnson'),
#  (['Andy', 'Hayes'], 'Hayes'),
#  (['Andy', 'Hensler'], 'Hensler'),
#  (['Andy', 'Long'], 'Long'),
#  (['Andy', 'Rose'], 'Rose'),
#  (['Andy', 'S.', 'Yun'], 'Yun'),
#  (['Andy', 'Stewart'], 'Stewart'),
#  (['Angel', 'A.', 'Figueredo'], 'Figueredo'),
#  (['Angel', 'Lomeli', 'Sanez'], 'Sanez'),
#  (['Angel', 'R.', 'Diaz'], 'Diaz'),
#  (['Angela', 'D.', 'Greene'], 'Greene'),
#  (['Angela', 'D.', 'Kirk'], 'Kirk'),
#  (['Angela', 'E.', 'Wiggins'], 'Wiggins'),
#  (['Angela', 'Eads', 'Tekell'], 'Tekell'),
#  (['Angela', 'Elliott', 'Frazier'], 'Frazier'),
#  (['Angela', 'F.', 'Stevens'], 'Stevens'),
#  (['Angela', 'G', 'Caine-Turner'], 'Caine-Turner'),
#  (['Angela', 'H.', 'Snider'], 'Snider'),
#  (['Angela', 'Hochmeister', 'Landes'], 'Landes'),
#  (['Angela', 'J.', 'Dailey'], 'Dailey'),
#  (['Angela', 'J.', 'Elpers'], 'Elpers'),
#  (['Angela', 'Keck'], 'Keck'),
#  (['Angela', 'L.', 'Arellanes'], 'Arellanes'),
#  (['Angela', 'L.', 'Burmeister'], 'Burmeister'),
#  (['Angela', 'Maria', 'Cancio,', 'Esq.'], 'Cancio'),
#  (['Angela', 'Pollard'], 'Pollard'),
#  (['Angela', 'Rich', 'Hartmann'], 'Hartmann'),
#  (['Angela', 'Tina', 'Vagotis'], 'Vagotis'),
#  (['Angelica', 'Del', 'Vecchio'], 'Vecchio'),
#  (['Angelica', 'McDonald'], 'McDonald'),
#  (['Angelita', 'Caldwell'], 'Caldwell'),
#  (['Angelo', 'A.', 'Plakas'], 'Plakas'),
#  (['Angelo', 'A.', 'Ziotas'], 'Ziotas'),
#  (['Angelo', 'C', 'Morresi'], 'Morresi'),
#  (['Angelo', 'C.', 'Testa'], 'Testa'),
#  (['Angelo', 'Cicchiello'], 'Cicchiello'),
#  (['Angelo', 'Marino', 'Jr.'], 'Marino'),
#  (['Angelo', 'R.', 'Simone'], 'Simone'),
#  (['Angelyn', 'M.', 'Wright'], 'Wright'),
#  (['Angus', 'Broward', 'Taff', 'Jr.'], 'Taff'),
#  (['Ani', 'A.', 'Avetisyan'], 'Avetisyan'),
#  (['Ani', 'Azadian'], 'Azadian'),
#  (['Anil', 'Taneja'], 'Taneja'),
#  (['Anita', 'A.', 'Webster'], 'Webster'),
#  (['Anita', 'Catharine', 'Johnson'], 'Johnson'),
#  (['Anita', 'Flannigan', 'Steenson'], 'Steenson'),
#  (['Anita', 'H.', 'Guidoux'], 'Guidoux'),
#  (['Anita', 'Hotchkiss'], 'Hotchkiss'),
#  (['Anita', 'L.', 'Clinton', 'Adams'], 'Adams'),
#  (['Anita', 'Modak-Truran'], 'Modak-Truran'),
#  (['Anita', 'O', 'Meara,', 'Esq.'], 'Meara'),
#  (['Anjan', 'Ganguly'], 'Ganguly'),
#  (['Ankesh', 'Sharma,', 'Esq.'], 'Sharma'),
#  (['Ann-Margaret', 'Perkins'], 'Perkins'),
#  (['Ann', 'Abrams', 'Price'], 'Price'),
#  (['Ann', 'E.', 'Buckley'], 'Buckley'),
#  (['Ann', 'Farrell', 'Leslie'], 'Leslie'),
#  (['Ann', 'Firestine', 'Foley'], 'Foley'),
#  (['Ann', 'G.', 'Davis'], 'Davis'),
#  (['Ann', 'H', 'Washburn'], 'Washburn'),
#  (['Ann', 'I.', 'Brandau'], 'Brandau'),
#  (['Ann', 'K.', 'Staley'], 'Staley'),
#  (['Ann', 'L', 'Nowak'], 'Nowak'),
#  (['Ann', 'LaCroix', 'Jones'], 'Jones'),
#  (['Ann', 'Lawler'], 'Lawler'),
#  (['Ann', 'Lyman', 'Steffens'], 'Steffens'),
#  (['Ann', 'M', 'Worthington'], 'Worthington'),
#  (['Ann', 'M.', 'Cushing,', 'Esq.'], 'Cushing'),
#  (['Ann', 'M.', 'Stockmaster'], 'Stockmaster'),
#  (['Ann', 'M.', 'Tessneer'], 'Tessneer'),
#  (['Ann', 'M.', 'Tobin-Levigne'], 'Tobin-Levigne'),
#  (['Ann', 'M.', 'Trzynka'], 'Trzynka'),
#  (['Ann', 'Marie', 'Henderson'], 'Henderson'),
#  (['Ann', 'R.', 'Combs'], 'Combs'),
#  (['Ann', 'S', 'Barker'], 'Barker'),
#  (['Ann', 'S.', 'Isobe'], 'Isobe'),
#  (['Ann', 'S.', 'Sheeley'], 'Sheeley'),
#  (['Ann', 'Sheridan', 'Siddall'], 'Siddall'),
#  (['Ann', 'Snow', 'Curry'], 'Curry'),
#  (['Ann', 'Tobin', 'Frank'], 'Frank'),
#  (['Ann', 'Trehub'], 'Trehub'),
#  (['Ann', 'Victoria', 'Hopcroft'], 'Hopcroft'),
#  (['Anna-Marie', 'Carter'], 'Carter'),
#  (['Anna', 'Burr'], 'Burr'),
#  (['Anna', 'C', 'Ortiz'], 'Ortiz'),
#  (['Anna', 'H.', 'Resnick'], 'Resnick'),
#  (['Anna', 'Marie', 'Williams'], 'Williams'),
#  (['Anna', 'P', 'Guerra'], 'Guerra'),
#  (['Anna', 'Petosky'], 'Petosky'),
#  (['Anna', 'Scheurich'], 'Scheurich'),
#  (['Anna', 'Villarreal'], 'Villarreal'),
#  (['Annalisa', 'Moore'], 'Moore'),
#  (['Annamarie', 'Donovan'], 'Donovan'),
#  (['Anne', 'B.', 'Fowler'], 'Fowler'),
#  (['Anne', 'C', 'Rice'], 'Rice'),
#  (['Anne', 'C', 'Skau'], 'Skau'),
#  (['Anne', 'C.', 'Leahey'], 'Leahey'),
#  (['Anne', 'G.', 'Brown'], 'Brown'),
#  (['Anne', 'Gale', 'Seider'], 'Seider'),
#  (['Anne', 'H.', 'S.', 'Fraser'], 'Fraser'),
#  (['Anne', 'Hamilton', 'Ford'], 'Ford'),
#  (['Anne', 'J', 'Daddario'], 'Daddario'),
#  (['Anne', 'J.', 'Kepner'], 'Kepner'),
#  (['Anne', 'J.', 'LaBella'], 'LaBella'),
#  (['Anne', 'K.', 'Guillory'], 'Guillory'),
#  (['Anne', 'K.', 'Manley'], 'Manley'),
#  (['Anne', 'Ketover', 'Watkins'], 'Watkins'),
#  (['Anne', 'L.', 'Berger'], 'Berger'),
#  (['Anne', 'L.', 'Heyns'], 'Heyns'),
#  (['Anne', 'L.', 'Morgan'], 'Morgan'),
#  ...]

# %%
first_name_list = []
title_list = ['mrs', 'hon']
for x in full_name_last_name_zip:
    first_name_found = False
    sub_name_index = 0
    #Find the number of sub-names in the name
    subnames_len = len(x[0])
    #Remove punctuation:
    while sub_name_index < subnames_len:
        #Get the current clean name
        clean_name = x[0][sub_name_index].translate(str.maketrans('', '', string.punctuation))
        if clean_name == x[1]:
            break
        #If the name is less than 2 characters, move to the next name
        if len(clean_name) <= 2 or clean_name.lower() in title_list:
            sub_name_index += 1
        else:
            first_name_found = True
            break
    if first_name_found:
        first_name_list.append(clean_name)
    else:
        first_name_list.append('')
first_name_list
# Out:
# ['Allsbrook',
#  'Elizabeth',
#  '',
#  'Joseph',
#  'Omotayo',
#  'Randolph',
#  'Blake',
#  'Bowdre',
#  'Bryan',
#  'Collin',
#  'Craig',
#  'David',
#  'Dawn',
#  'Dwight',
#  'Gregory',
#  'Gus',
#  'Harold',
#  'Howard',
#  'Stacey',
#  '',
#  'Jack',
#  'James',
#  'Jeff',
#  'Lance',
#  'Lou',
#  'Mac',
#  'Major',
#  'Mark',
#  'Michael',
#  'Newton',
#  '',
#  '',
#  'Paul',
#  'Paul',
#  'Philip',
#  'Powell',
#  'Randall',
#  'Richard',
#  'Robert',
#  'Robert',
#  'Ronald',
#  'Roy',
#  'Russell',
#  'Scot',
#  'Scott',
#  'Shane',
#  'Spencer',
#  'Troy',
#  'Tony',
#  'Wade',
#  'William',
#  '',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Aaron',
#  'Abbe',
#  'Abbott',
#  'Abby',
#  'Abby',
#  'Abdalla',
#  'Abdulhakim',
#  'Abe',
#  'Abe',
#  'Abel',
#  'Abelino',
#  'Abraham',
#  'Abraham',
#  'Abraham',
#  'Abraham',
#  'Abraham',
#  'Abraham',
#  'Ada',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Adam',
#  'Addison',
#  'Adele',
#  'Adele',
#  'Adnan',
#  'Adolfo',
#  'AdoLisa',
#  'Adolph',
#  'Adolph',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adrian',
#  'Adriel',
#  'Adrien',
#  'Adrienne',
#  'Adrienne',
#  'Adrienne',
#  'Adrienne',
#  'Adrienne',
#  'Adrienne',
#  'Adrienne',
#  'Adrienne',
#  'Agatha',
#  'Agnes',
#  'Agostinho',
#  'Agostino',
#  'Aidan',
#  'Aihui',
#  'Aiken',
#  'Aileen',
#  'Aileen',
#  'Aimee',
#  'Aisling',
#  'Aksana',
#  '',
#  '',
#  'Joseph',
#  '',
#  '',
#  'Alali',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alan',
#  'Alana',
#  'Alaric',
#  'Alban',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Albert',
#  'Alberto',
#  'Alberto',
#  'Alberto',
#  'Alberto',
#  'Alden',
#  'Aldo',
#  'Aldo',
#  'Alec',
#  'Alec',
#  'Alecia',
#  'Alejandro',
#  'Alejandro',
#  'Alejandro',
#  'Alesia',
#  'Alesia',
#  'Alessandro',
#  'Alessandro',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alex',
#  'Alexa',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexandra',
#  'Alexandra',
#  'Alexandra',
#  'Alexandre',
#  'Alexia',
#  'Alexis',
#  'Alexis',
#  'Alf',
#  'Alf',
#  'Alford',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfred',
#  'Alfredo',
#  'Ali',
#  'Ali',
#  'Alice',
#  'Alice',
#  'Alice',
#  'Alice',
#  'Alice',
#  'Alice',
#  'Alicia',
#  'Alicia',
#  'Alicia',
#  'Aline',
#  'Alisa',
#  'Alisa',
#  'Alison',
#  'Alison',
#  'Alison',
#  'Alison',
#  'Alison',
#  'Alison',
#  'Alison',
#  'Alissa',
#  'Alissa',
#  'Alistair',
#  'Alister',
#  'Alivia',
#  'Alix',
#  'Alix',
#  'Allain',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allan',
#  'Allegra',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allen',
#  'Allette',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allison',
#  'Allyson',
#  'Alma',
#  'Almis',
#  'Alok',
#  'Alphonso',
#  'Altagracia',
#  'Altom',
#  'Alton',
#  'Alton',
#  'Alton',
#  'Alton',
#  'Alton',
#  'Alvand',
#  'Alvarene',
#  'Alvaro',
#  'Alvin',
#  'Alvin',
#  'Alvin',
#  'Alvin',
#  'Alvin',
#  'Alvin',
#  'Alvin',
#  'Alvin',
#  'Alvin',
#  'Alvin',
#  'Alwyn',
#  'Alyse',
#  'Alyson',
#  'Alyson',
#  'Alyssa',
#  'Alyssa',
#  'Alyssa',
#  'Alyssa',
#  'Amala',
#  'Amalia',
#  'Aman',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amanda',
#  'Amar',
#  'Amarante',
#  'Ambar',
#  'Amber',
#  'Amber',
#  'Amber',
#  'Ameli',
#  'Amelia',
#  'Americo',
#  'Amiee',
#  'Amir',
#  'Amit',
#  'Ammar',
#  'Amme',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Amy',
#  'Ana',
#  'Ana',
#  'Ana',
#  'Ana',
#  'Ana',
#  'Ana',
#  'Ana',
#  'Ana',
#  'Analisa',
#  'Anand',
#  'Anat',
#  'Anatta',
#  'Ancil',
#  'Anderson',
#  'Anderson',
#  'Andis',
#  'Andre',
#  'AnDre',
#  'Andre',
#  'Andre',
#  'Andre',
#  'Andre',
#  'Andre',
#  'Andre',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andrea',
#  'Andres',
#  'Andres',
#  'Andres',
#  'Andres',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Andrewe',
#  'Andy',
#  'Andy',
#  'Andy',
#  'Andy',
#  'Andy',
#  'Andy',
#  'Angel',
#  'Angel',
#  'Angel',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angelica',
#  'Angelica',
#  'Angelita',
#  'Angelo',
#  'Angelo',
#  'Angelo',
#  'Angelo',
#  'Angelo',
#  'Angelo',
#  'Angelo',
#  'Angelyn',
#  'Angus',
#  'Ani',
#  'Ani',
#  'Anil',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Anita',
#  'Anjan',
#  'Ankesh',
#  'AnnMargaret',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'Ann',
#  'AnnaMarie',
#  'Anna',
#  'Anna',
#  'Anna',
#  'Anna',
#  'Anna',
#  'Anna',
#  'Anna',
#  'Anna',
#  'Annalisa',
#  'Annamarie',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  ...]

# %%
df.insert(1, 'first name', first_name_list)
df.insert(1, 'surname', last_name_list)
df['state'] = df['state'].apply(lambda x: x.lower())
df.drop(df[df['state'] == 'no data'].index, inplace = True)
df = df.rename(columns={"fips": "county"})

# %%
df['county'] = df['county'].astype(str)
col_list = ['surname', 'first name', 'name', 'state', 'county']
df = df[col_list]
df.to_csv('Dec_12_name_zip_fips_state_with_names.csv')
